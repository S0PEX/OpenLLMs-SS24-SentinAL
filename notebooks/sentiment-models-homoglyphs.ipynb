# %% [markdown]
# ### Import models

# %%
import pandas as pd
from models import CardiffnlpTwitterRobertaBaseSentimentLatest, DistilrobertaFinetunedFinancialNewsSentimentAnalysis

# %% [markdown]
# ### Instantiate & test models

# %%
twitter_roberta = CardiffnlpTwitterRobertaBaseSentimentLatest()
financial_news_roberta = DistilrobertaFinetunedFinancialNewsSentimentAnalysis()
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
input_text = "I love the weather today!"
print("Twitter sentiment:", twitter_roberta.evaluate(input_text))
print("Financial news sentiment:", financial_news_roberta.evaluate(input_text))
# Out:
# Twitter sentiment: [{'label': 'positive', 'score': 0.9834305047988892}]
# Financial news sentiment: [{'label': 'neutral', 'score': 0.9990911483764648}]

# %% [markdown]
# # Load Datasets

# %%
from datasets import load_from_disk

tweet_eval = load_from_disk("../data/processed/tweet_eval_homoglyph")
financial_phrasebank = load_from_disk("../data/processed/financial_phrasebank_homoglyph")

# %%
print(f'Tweet eval dataset: {tweet_eval}')
print(f'Financial phrasebank dataset: {financial_phrasebank}')
# Out:
# Tweet eval dataset: Dataset({
#     features: ['text', 'label'],
#     num_rows: 1252
# })
# Financial phrasebank dataset: Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 303
# })

# %% [markdown]
# # Evaluate models on datasets

# %%
display(tweet_eval.features)
display(financial_phrasebank.features)
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['non-hate', 'hate'], id=None)}
# {'sentence': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['negative', 'neutral', 'positive'], id=None)}

# %%
tweet_eval_results = {
    'twitter_roberta': twitter_roberta.evaluate_dataset(tweet_eval, feature='text'),
    'financial_news_roberta': financial_news_roberta.evaluate_dataset(tweet_eval, feature='text')
}

# %%
display(tweet_eval_results)
# Out:
# {'twitter_roberta': [[{'label': 'neutral', 'score': 0.7997302412986755}],
#   [{'label': 'neutral', 'score': 0.6987196207046509}],
#   [{'label': 'neutral', 'score': 0.8277277946472168}],
#   [{'label': 'neutral', 'score': 0.8162309527397156}],
#   [{'label': 'neutral', 'score': 0.8549603819847107}],
#   [{'label': 'neutral', 'score': 0.813928484916687}],
#   [{'label': 'neutral', 'score': 0.7251846194267273}],
#   [{'label': 'neutral', 'score': 0.7976133227348328}],
#   [{'label': 'neutral', 'score': 0.802094578742981}],
#   [{'label': 'neutral', 'score': 0.7974727749824524}],
#   [{'label': 'neutral', 'score': 0.8239505887031555}],
#   [{'label': 'neutral', 'score': 0.7930537462234497}],
#   [{'label': 'neutral', 'score': 0.8318130373954773}],
#   [{'label': 'neutral', 'score': 0.8250578045845032}],
#   [{'label': 'neutral', 'score': 0.7436833381652832}],
#   [{'label': 'neutral', 'score': 0.8257061243057251}],
#   [{'label': 'neutral', 'score': 0.8056649565696716}],
#   [{'label': 'neutral', 'score': 0.5827032923698425}],
#   [{'label': 'neutral', 'score': 0.8284568786621094}],
#   [{'label': 'neutral', 'score': 0.7661019563674927}],
#   [{'label': 'neutral', 'score': 0.8399744629859924}],
#   [{'label': 'neutral', 'score': 0.8054525852203369}],
#   [{'label': 'neutral', 'score': 0.7969728708267212}],
#   [{'label': 'neutral', 'score': 0.8524917960166931}],
#   [{'label': 'neutral', 'score': 0.7812241315841675}],
#   [{'label': 'neutral', 'score': 0.8058440685272217}],
#   [{'label': 'neutral', 'score': 0.7952610850334167}],
#   [{'label': 'neutral', 'score': 0.8284305334091187}],
#   [{'label': 'neutral', 'score': 0.8417012095451355}],
#   [{'label': 'neutral', 'score': 0.8196282386779785}],
#   [{'label': 'neutral', 'score': 0.7875922918319702}],
#   [{'label': 'neutral', 'score': 0.7781548500061035}],
#   [{'label': 'neutral', 'score': 0.8265038132667542}],
#   [{'label': 'neutral', 'score': 0.8156614899635315}],
#   [{'label': 'neutral', 'score': 0.874975860118866}],
#   [{'label': 'neutral', 'score': 0.8113877177238464}],
#   [{'label': 'neutral', 'score': 0.8338186740875244}],
#   [{'label': 'neutral', 'score': 0.8152744770050049}],
#   [{'label': 'neutral', 'score': 0.8473384380340576}],
#   [{'label': 'neutral', 'score': 0.8092255592346191}],
#   [{'label': 'neutral', 'score': 0.7814987301826477}],
#   [{'label': 'neutral', 'score': 0.7850844264030457}],
#   [{'label': 'neutral', 'score': 0.8442551493644714}],
#   [{'label': 'neutral', 'score': 0.806110143661499}],
#   [{'label': 'neutral', 'score': 0.7836962342262268}],
#   [{'label': 'neutral', 'score': 0.8460654020309448}],
#   [{'label': 'neutral', 'score': 0.834614098072052}],
#   [{'label': 'neutral', 'score': 0.7986983060836792}],
#   [{'label': 'neutral', 'score': 0.8425697088241577}],
#   [{'label': 'neutral', 'score': 0.826220691204071}],
#   [{'label': 'neutral', 'score': 0.7781402468681335}],
#   [{'label': 'neutral', 'score': 0.8013117909431458}],
#   [{'label': 'neutral', 'score': 0.8207647204399109}],
#   [{'label': 'neutral', 'score': 0.8303779363632202}],
#   [{'label': 'neutral', 'score': 0.7305724024772644}],
#   [{'label': 'neutral', 'score': 0.8008216619491577}],
#   [{'label': 'neutral', 'score': 0.8094783425331116}],
#   [{'label': 'neutral', 'score': 0.8320075273513794}],
#   [{'label': 'neutral', 'score': 0.8321001529693604}],
#   [{'label': 'neutral', 'score': 0.8307951092720032}],
#   [{'label': 'neutral', 'score': 0.8283554911613464}],
#   [{'label': 'neutral', 'score': 0.7701347470283508}],
#   [{'label': 'neutral', 'score': 0.7944413423538208}],
#   [{'label': 'neutral', 'score': 0.8302779793739319}],
#   [{'label': 'neutral', 'score': 0.7615249156951904}],
#   [{'label': 'neutral', 'score': 0.8231536149978638}],
#   [{'label': 'neutral', 'score': 0.8263712525367737}],
#   [{'label': 'neutral', 'score': 0.8453208208084106}],
#   [{'label': 'neutral', 'score': 0.8082728385925293}],
#   [{'label': 'neutral', 'score': 0.8286562561988831}],
#   [{'label': 'neutral', 'score': 0.810093104839325}],
#   [{'label': 'neutral', 'score': 0.8267564177513123}],
#   [{'label': 'neutral', 'score': 0.8310248851776123}],
#   [{'label': 'neutral', 'score': 0.7951204180717468}],
#   [{'label': 'neutral', 'score': 0.8335219025611877}],
#   [{'label': 'neutral', 'score': 0.884533703327179}],
#   [{'label': 'neutral', 'score': 0.791109561920166}],
#   [{'label': 'neutral', 'score': 0.8346093893051147}],
#   [{'label': 'neutral', 'score': 0.8471264839172363}],
#   [{'label': 'neutral', 'score': 0.8573797941207886}],
#   [{'label': 'neutral', 'score': 0.8190104365348816}],
#   [{'label': 'neutral', 'score': 0.7965336441993713}],
#   [{'label': 'neutral', 'score': 0.8123257756233215}],
#   [{'label': 'neutral', 'score': 0.7794885635375977}],
#   [{'label': 'neutral', 'score': 0.8399898409843445}],
#   [{'label': 'neutral', 'score': 0.7801331281661987}],
#   [{'label': 'neutral', 'score': 0.88386470079422}],
#   [{'label': 'neutral', 'score': 0.7791479229927063}],
#   [{'label': 'neutral', 'score': 0.8086481094360352}],
#   [{'label': 'neutral', 'score': 0.8376482129096985}],
#   [{'label': 'neutral', 'score': 0.8079096078872681}],
#   [{'label': 'neutral', 'score': 0.8189999461174011}],
#   [{'label': 'neutral', 'score': 0.8194421529769897}],
#   [{'label': 'neutral', 'score': 0.8345897197723389}],
#   [{'label': 'neutral', 'score': 0.8150174617767334}],
#   [{'label': 'neutral', 'score': 0.7594305276870728}],
#   [{'label': 'neutral', 'score': 0.7900168895721436}],
#   [{'label': 'neutral', 'score': 0.8068885803222656}],
#   [{'label': 'neutral', 'score': 0.8255269527435303}],
#   [{'label': 'neutral', 'score': 0.7823184132575989}],
#   [{'label': 'neutral', 'score': 0.7550005316734314}],
#   [{'label': 'neutral', 'score': 0.8017500638961792}],
#   [{'label': 'neutral', 'score': 0.8292364478111267}],
#   [{'label': 'neutral', 'score': 0.8455994725227356}],
#   [{'label': 'neutral', 'score': 0.7865188121795654}],
#   [{'label': 'neutral', 'score': 0.7496784329414368}],
#   [{'label': 'neutral', 'score': 0.7795163989067078}],
#   [{'label': 'neutral', 'score': 0.7776724696159363}],
#   [{'label': 'neutral', 'score': 0.8182390332221985}],
#   [{'label': 'neutral', 'score': 0.8272026777267456}],
#   [{'label': 'neutral', 'score': 0.8495170474052429}],
#   [{'label': 'neutral', 'score': 0.8203046917915344}],
#   [{'label': 'neutral', 'score': 0.8103153109550476}],
#   [{'label': 'neutral', 'score': 0.8326478600502014}],
#   [{'label': 'neutral', 'score': 0.781491219997406}],
#   [{'label': 'neutral', 'score': 0.8495174050331116}],
#   [{'label': 'neutral', 'score': 0.8066878914833069}],
#   [{'label': 'neutral', 'score': 0.8453613519668579}],
#   [{'label': 'neutral', 'score': 0.7915247678756714}],
#   [{'label': 'neutral', 'score': 0.7795296907424927}],
#   [{'label': 'neutral', 'score': 0.7868884801864624}],
#   [{'label': 'neutral', 'score': 0.835703432559967}],
#   [{'label': 'neutral', 'score': 0.8532277941703796}],
#   [{'label': 'neutral', 'score': 0.795616865158081}],
#   [{'label': 'neutral', 'score': 0.8961220383644104}],
#   [{'label': 'neutral', 'score': 0.8203245997428894}],
#   [{'label': 'neutral', 'score': 0.8539021015167236}],
#   [{'label': 'neutral', 'score': 0.8241834044456482}],
#   [{'label': 'neutral', 'score': 0.7915101051330566}],
#   [{'label': 'neutral', 'score': 0.8136930465698242}],
#   [{'label': 'neutral', 'score': 0.8137423396110535}],
#   [{'label': 'neutral', 'score': 0.7952882051467896}],
#   [{'label': 'neutral', 'score': 0.8276209831237793}],
#   [{'label': 'neutral', 'score': 0.8355959057807922}],
#   [{'label': 'neutral', 'score': 0.83161461353302}],
#   [{'label': 'neutral', 'score': 0.8190359473228455}],
#   [{'label': 'neutral', 'score': 0.8315483927726746}],
#   [{'label': 'neutral', 'score': 0.7940704822540283}],
#   [{'label': 'neutral', 'score': 0.7257393598556519}],
#   [{'label': 'neutral', 'score': 0.8669109344482422}],
#   [{'label': 'neutral', 'score': 0.8563277721405029}],
#   [{'label': 'neutral', 'score': 0.8470932841300964}],
#   [{'label': 'neutral', 'score': 0.8089398741722107}],
#   [{'label': 'neutral', 'score': 0.8083319067955017}],
#   [{'label': 'neutral', 'score': 0.8194187879562378}],
#   [{'label': 'neutral', 'score': 0.8327401876449585}],
#   [{'label': 'neutral', 'score': 0.8312705755233765}],
#   [{'label': 'neutral', 'score': 0.7181883454322815}],
#   [{'label': 'neutral', 'score': 0.8261683583259583}],
#   [{'label': 'neutral', 'score': 0.8470097184181213}],
#   [{'label': 'neutral', 'score': 0.836117148399353}],
#   [{'label': 'neutral', 'score': 0.8344869017601013}],
#   [{'label': 'neutral', 'score': 0.8248711228370667}],
#   [{'label': 'neutral', 'score': 0.8112126588821411}],
#   [{'label': 'neutral', 'score': 0.8464451432228088}],
#   [{'label': 'neutral', 'score': 0.7979798316955566}],
#   [{'label': 'neutral', 'score': 0.8053337335586548}],
#   [{'label': 'neutral', 'score': 0.8025574088096619}],
#   [{'label': 'neutral', 'score': 0.7980733513832092}],
#   [{'label': 'neutral', 'score': 0.8707923889160156}],
#   [{'label': 'neutral', 'score': 0.8376728296279907}],
#   [{'label': 'neutral', 'score': 0.8142911195755005}],
#   [{'label': 'neutral', 'score': 0.8262221813201904}],
#   [{'label': 'neutral', 'score': 0.8045088648796082}],
#   [{'label': 'neutral', 'score': 0.8283848166465759}],
#   [{'label': 'neutral', 'score': 0.7955226302146912}],
#   [{'label': 'positive', 'score': 0.6951435208320618}],
#   [{'label': 'neutral', 'score': 0.8705694675445557}],
#   [{'label': 'neutral', 'score': 0.884856641292572}],
#   [{'label': 'neutral', 'score': 0.8023537993431091}],
#   [{'label': 'neutral', 'score': 0.7965956926345825}],
#   [{'label': 'neutral', 'score': 0.8238441944122314}],
#   [{'label': 'neutral', 'score': 0.8562084436416626}],
#   [{'label': 'neutral', 'score': 0.8832730054855347}],
#   [{'label': 'neutral', 'score': 0.849251925945282}],
#   [{'label': 'neutral', 'score': 0.8427783846855164}],
#   [{'label': 'neutral', 'score': 0.8682006001472473}],
#   [{'label': 'neutral', 'score': 0.8161213994026184}],
#   [{'label': 'neutral', 'score': 0.7795097231864929}],
#   [{'label': 'neutral', 'score': 0.8041192293167114}],
#   [{'label': 'neutral', 'score': 0.8634119033813477}],
#   [{'label': 'neutral', 'score': 0.8039587736129761}],
#   [{'label': 'neutral', 'score': 0.8503092527389526}],
#   [{'label': 'neutral', 'score': 0.8216512203216553}],
#   [{'label': 'neutral', 'score': 0.8469942212104797}],
#   [{'label': 'neutral', 'score': 0.8088473677635193}],
#   [{'label': 'neutral', 'score': 0.7887137532234192}],
#   [{'label': 'neutral', 'score': 0.803673505783081}],
#   [{'label': 'neutral', 'score': 0.8164900541305542}],
#   [{'label': 'neutral', 'score': 0.8214436769485474}],
#   [{'label': 'neutral', 'score': 0.7971878051757812}],
#   [{'label': 'neutral', 'score': 0.8153377175331116}],
#   [{'label': 'neutral', 'score': 0.7749174237251282}],
#   [{'label': 'neutral', 'score': 0.8316951394081116}],
#   [{'label': 'neutral', 'score': 0.8200943470001221}],
#   [{'label': 'neutral', 'score': 0.7739613056182861}],
#   [{'label': 'neutral', 'score': 0.794840931892395}],
#   [{'label': 'neutral', 'score': 0.8373605608940125}],
#   [{'label': 'neutral', 'score': 0.8437279462814331}],
#   [{'label': 'neutral', 'score': 0.8384801149368286}],
#   [{'label': 'neutral', 'score': 0.8125705718994141}],
#   [{'label': 'neutral', 'score': 0.7785554528236389}],
#   [{'label': 'neutral', 'score': 0.8569349050521851}],
#   [{'label': 'neutral', 'score': 0.785495936870575}],
#   [{'label': 'neutral', 'score': 0.8235244750976562}],
#   [{'label': 'neutral', 'score': 0.877881646156311}],
#   [{'label': 'positive', 'score': 0.5090754628181458}],
#   [{'label': 'neutral', 'score': 0.8185641765594482}],
#   [{'label': 'neutral', 'score': 0.8216610550880432}],
#   [{'label': 'neutral', 'score': 0.8917638659477234}],
#   [{'label': 'neutral', 'score': 0.8062607049942017}],
#   [{'label': 'neutral', 'score': 0.803462028503418}],
#   [{'label': 'neutral', 'score': 0.8421268463134766}],
#   [{'label': 'neutral', 'score': 0.7936195135116577}],
#   [{'label': 'neutral', 'score': 0.8173595666885376}],
#   [{'label': 'neutral', 'score': 0.8543812036514282}],
#   [{'label': 'neutral', 'score': 0.8173206448554993}],
#   [{'label': 'neutral', 'score': 0.8120992183685303}],
#   [{'label': 'neutral', 'score': 0.782647430896759}],
#   [{'label': 'neutral', 'score': 0.8423202037811279}],
#   [{'label': 'neutral', 'score': 0.7865673899650574}],
#   [{'label': 'neutral', 'score': 0.8266539573669434}],
#   [{'label': 'neutral', 'score': 0.7793712615966797}],
#   [{'label': 'neutral', 'score': 0.7915745377540588}],
#   [{'label': 'neutral', 'score': 0.7980422377586365}],
#   [{'label': 'neutral', 'score': 0.8069266676902771}],
#   [{'label': 'neutral', 'score': 0.8015011548995972}],
#   [{'label': 'neutral', 'score': 0.831063449382782}],
#   [{'label': 'neutral', 'score': 0.8660122752189636}],
#   [{'label': 'neutral', 'score': 0.7847391366958618}],
#   [{'label': 'neutral', 'score': 0.831601083278656}],
#   [{'label': 'neutral', 'score': 0.7918221950531006}],
#   [{'label': 'neutral', 'score': 0.7795401215553284}],
#   [{'label': 'neutral', 'score': 0.8602375388145447}],
#   [{'label': 'neutral', 'score': 0.891323447227478}],
#   [{'label': 'neutral', 'score': 0.8770907521247864}],
#   [{'label': 'neutral', 'score': 0.7698994874954224}],
#   [{'label': 'neutral', 'score': 0.7906284928321838}],
#   [{'label': 'neutral', 'score': 0.7987868785858154}],
#   [{'label': 'neutral', 'score': 0.7831552624702454}],
#   [{'label': 'neutral', 'score': 0.8101639747619629}],
#   [{'label': 'neutral', 'score': 0.6635429859161377}],
#   [{'label': 'neutral', 'score': 0.8699883818626404}],
#   [{'label': 'neutral', 'score': 0.8514490723609924}],
#   [{'label': 'neutral', 'score': 0.8240190744400024}],
#   [{'label': 'neutral', 'score': 0.8191788196563721}],
#   [{'label': 'neutral', 'score': 0.80140620470047}],
#   [{'label': 'neutral', 'score': 0.8044624924659729}],
#   [{'label': 'neutral', 'score': 0.7898263335227966}],
#   [{'label': 'neutral', 'score': 0.7687567472457886}],
#   [{'label': 'neutral', 'score': 0.8033060431480408}],
#   [{'label': 'neutral', 'score': 0.8301510214805603}],
#   [{'label': 'neutral', 'score': 0.8398693799972534}],
#   [{'label': 'neutral', 'score': 0.8186080455780029}],
#   [{'label': 'neutral', 'score': 0.8140169382095337}],
#   [{'label': 'neutral', 'score': 0.8245965838432312}],
#   [{'label': 'neutral', 'score': 0.8444151282310486}],
#   [{'label': 'neutral', 'score': 0.8051491975784302}],
#   [{'label': 'neutral', 'score': 0.8008437752723694}],
#   [{'label': 'neutral', 'score': 0.8047223687171936}],
#   [{'label': 'neutral', 'score': 0.7793333530426025}],
#   [{'label': 'neutral', 'score': 0.8126726150512695}],
#   [{'label': 'neutral', 'score': 0.8648485541343689}],
#   [{'label': 'neutral', 'score': 0.8283112645149231}],
#   [{'label': 'neutral', 'score': 0.7855084538459778}],
#   [{'label': 'neutral', 'score': 0.8223844170570374}],
#   [{'label': 'neutral', 'score': 0.8112260699272156}],
#   [{'label': 'neutral', 'score': 0.8001343011856079}],
#   [{'label': 'neutral', 'score': 0.7788543105125427}],
#   [{'label': 'neutral', 'score': 0.7989028692245483}],
#   [{'label': 'neutral', 'score': 0.8136422634124756}],
#   [{'label': 'neutral', 'score': 0.7697556614875793}],
#   [{'label': 'neutral', 'score': 0.7743765115737915}],
#   [{'label': 'neutral', 'score': 0.7907946705818176}],
#   [{'label': 'neutral', 'score': 0.8053692579269409}],
#   [{'label': 'neutral', 'score': 0.7683238983154297}],
#   [{'label': 'neutral', 'score': 0.8114983439445496}],
#   [{'label': 'neutral', 'score': 0.7987938523292542}],
#   [{'label': 'neutral', 'score': 0.780386209487915}],
#   [{'label': 'neutral', 'score': 0.8476434946060181}],
#   [{'label': 'neutral', 'score': 0.806470513343811}],
#   [{'label': 'neutral', 'score': 0.8914584517478943}],
#   [{'label': 'neutral', 'score': 0.8465664982795715}],
#   [{'label': 'neutral', 'score': 0.8396130204200745}],
#   [{'label': 'neutral', 'score': 0.9011561274528503}],
#   [{'label': 'neutral', 'score': 0.7983242869377136}],
#   [{'label': 'neutral', 'score': 0.8609333038330078}],
#   [{'label': 'neutral', 'score': 0.8237326741218567}],
#   [{'label': 'neutral', 'score': 0.8112288117408752}],
#   [{'label': 'neutral', 'score': 0.7895265817642212}],
#   [{'label': 'neutral', 'score': 0.7788540124893188}],
#   [{'label': 'neutral', 'score': 0.8315748572349548}],
#   [{'label': 'neutral', 'score': 0.8198153972625732}],
#   [{'label': 'neutral', 'score': 0.8006482720375061}],
#   [{'label': 'neutral', 'score': 0.7862038016319275}],
#   [{'label': 'neutral', 'score': 0.7884482741355896}],
#   [{'label': 'neutral', 'score': 0.780622124671936}],
#   [{'label': 'neutral', 'score': 0.8329582214355469}],
#   [{'label': 'neutral', 'score': 0.8068701028823853}],
#   [{'label': 'neutral', 'score': 0.8042507767677307}],
#   [{'label': 'neutral', 'score': 0.6864899396896362}],
#   [{'label': 'neutral', 'score': 0.7863615155220032}],
#   [{'label': 'neutral', 'score': 0.8284283876419067}],
#   [{'label': 'neutral', 'score': 0.823190450668335}],
#   [{'label': 'neutral', 'score': 0.770652711391449}],
#   [{'label': 'neutral', 'score': 0.875293493270874}],
#   [{'label': 'neutral', 'score': 0.8029089570045471}],
#   [{'label': 'neutral', 'score': 0.8703321218490601}],
#   [{'label': 'neutral', 'score': 0.874643087387085}],
#   [{'label': 'neutral', 'score': 0.8415546417236328}],
#   [{'label': 'neutral', 'score': 0.7955384850502014}],
#   [{'label': 'neutral', 'score': 0.7502549290657043}],
#   [{'label': 'neutral', 'score': 0.8516474366188049}],
#   [{'label': 'neutral', 'score': 0.7878397703170776}],
#   [{'label': 'neutral', 'score': 0.7948523759841919}],
#   [{'label': 'neutral', 'score': 0.8203232288360596}],
#   [{'label': 'neutral', 'score': 0.847701907157898}],
#   [{'label': 'neutral', 'score': 0.8114970326423645}],
#   [{'label': 'neutral', 'score': 0.795043408870697}],
#   [{'label': 'neutral', 'score': 0.8614509701728821}],
#   [{'label': 'neutral', 'score': 0.7982624769210815}],
#   [{'label': 'neutral', 'score': 0.8051652908325195}],
#   [{'label': 'neutral', 'score': 0.8140606880187988}],
#   [{'label': 'neutral', 'score': 0.7982977628707886}],
#   [{'label': 'neutral', 'score': 0.7954567074775696}],
#   [{'label': 'neutral', 'score': 0.7838588953018188}],
#   [{'label': 'neutral', 'score': 0.8413146734237671}],
#   [{'label': 'neutral', 'score': 0.847364604473114}],
#   [{'label': 'neutral', 'score': 0.805941641330719}],
#   [{'label': 'neutral', 'score': 0.7570528984069824}],
#   [{'label': 'neutral', 'score': 0.8515430092811584}],
#   [{'label': 'neutral', 'score': 0.7994472980499268}],
#   [{'label': 'neutral', 'score': 0.8555564880371094}],
#   [{'label': 'neutral', 'score': 0.8102058172225952}],
#   [{'label': 'neutral', 'score': 0.8201176524162292}],
#   [{'label': 'neutral', 'score': 0.7984819412231445}],
#   [{'label': 'neutral', 'score': 0.9143287539482117}],
#   [{'label': 'neutral', 'score': 0.7763421535491943}],
#   [{'label': 'neutral', 'score': 0.847175657749176}],
#   [{'label': 'neutral', 'score': 0.7974635362625122}],
#   [{'label': 'neutral', 'score': 0.7560043931007385}],
#   [{'label': 'neutral', 'score': 0.7938556671142578}],
#   [{'label': 'neutral', 'score': 0.804340124130249}],
#   [{'label': 'neutral', 'score': 0.8631966710090637}],
#   [{'label': 'neutral', 'score': 0.7925450801849365}],
#   [{'label': 'neutral', 'score': 0.8031057119369507}],
#   [{'label': 'neutral', 'score': 0.8217793107032776}],
#   [{'label': 'neutral', 'score': 0.8304877281188965}],
#   [{'label': 'neutral', 'score': 0.794531524181366}],
#   [{'label': 'neutral', 'score': 0.7706654071807861}],
#   [{'label': 'neutral', 'score': 0.7688632607460022}],
#   [{'label': 'neutral', 'score': 0.8190804123878479}],
#   [{'label': 'neutral', 'score': 0.8317602872848511}],
#   [{'label': 'neutral', 'score': 0.8195812702178955}],
#   [{'label': 'neutral', 'score': 0.8376116752624512}],
#   [{'label': 'neutral', 'score': 0.8201180100440979}],
#   [{'label': 'neutral', 'score': 0.8021640181541443}],
#   [{'label': 'neutral', 'score': 0.8611119389533997}],
#   [{'label': 'neutral', 'score': 0.7981460690498352}],
#   [{'label': 'neutral', 'score': 0.807245135307312}],
#   [{'label': 'neutral', 'score': 0.7775596380233765}],
#   [{'label': 'neutral', 'score': 0.8089378476142883}],
#   [{'label': 'neutral', 'score': 0.7960721850395203}],
#   [{'label': 'neutral', 'score': 0.7586990594863892}],
#   [{'label': 'neutral', 'score': 0.8014005422592163}],
#   [{'label': 'neutral', 'score': 0.771290123462677}],
#   [{'label': 'neutral', 'score': 0.8360827565193176}],
#   [{'label': 'neutral', 'score': 0.8113394975662231}],
#   [{'label': 'neutral', 'score': 0.7971364259719849}],
#   [{'label': 'neutral', 'score': 0.8243927955627441}],
#   [{'label': 'neutral', 'score': 0.7881287336349487}],
#   [{'label': 'neutral', 'score': 0.8369522094726562}],
#   [{'label': 'neutral', 'score': 0.8044041395187378}],
#   [{'label': 'neutral', 'score': 0.8323912024497986}],
#   [{'label': 'neutral', 'score': 0.7711301445960999}],
#   [{'label': 'neutral', 'score': 0.7912628650665283}],
#   [{'label': 'neutral', 'score': 0.8567408323287964}],
#   [{'label': 'neutral', 'score': 0.5145851373672485}],
#   [{'label': 'neutral', 'score': 0.8478605151176453}],
#   [{'label': 'neutral', 'score': 0.8571667075157166}],
#   [{'label': 'neutral', 'score': 0.8091319799423218}],
#   [{'label': 'neutral', 'score': 0.8098382949829102}],
#   [{'label': 'neutral', 'score': 0.8042332530021667}],
#   [{'label': 'neutral', 'score': 0.8489810824394226}],
#   [{'label': 'neutral', 'score': 0.828417956829071}],
#   [{'label': 'neutral', 'score': 0.7900390625}],
#   [{'label': 'neutral', 'score': 0.7690887451171875}],
#   [{'label': 'neutral', 'score': 0.7571234107017517}],
#   [{'label': 'neutral', 'score': 0.8228617906570435}],
#   [{'label': 'neutral', 'score': 0.7527734041213989}],
#   [{'label': 'neutral', 'score': 0.8289397358894348}],
#   [{'label': 'neutral', 'score': 0.8040780425071716}],
#   [{'label': 'neutral', 'score': 0.7730526924133301}],
#   [{'label': 'neutral', 'score': 0.8000797629356384}],
#   [{'label': 'neutral', 'score': 0.8186312913894653}],
#   [{'label': 'neutral', 'score': 0.8185784816741943}],
#   [{'label': 'neutral', 'score': 0.8351648449897766}],
#   [{'label': 'neutral', 'score': 0.8031144738197327}],
#   [{'label': 'neutral', 'score': 0.6442310214042664}],
#   [{'label': 'neutral', 'score': 0.819943368434906}],
#   [{'label': 'neutral', 'score': 0.8231861591339111}],
#   [{'label': 'neutral', 'score': 0.8053811192512512}],
#   [{'label': 'neutral', 'score': 0.7995691895484924}],
#   [{'label': 'neutral', 'score': 0.8104462027549744}],
#   [{'label': 'neutral', 'score': 0.8565537929534912}],
#   [{'label': 'neutral', 'score': 0.799759566783905}],
#   [{'label': 'neutral', 'score': 0.8184544444084167}],
#   [{'label': 'neutral', 'score': 0.7729597687721252}],
#   [{'label': 'neutral', 'score': 0.8115777373313904}],
#   [{'label': 'neutral', 'score': 0.8474828600883484}],
#   [{'label': 'neutral', 'score': 0.7268385291099548}],
#   [{'label': 'neutral', 'score': 0.8425427675247192}],
#   [{'label': 'neutral', 'score': 0.7924678325653076}],
#   [{'label': 'neutral', 'score': 0.7902826070785522}],
#   [{'label': 'neutral', 'score': 0.7527201175689697}],
#   [{'label': 'neutral', 'score': 0.8176934719085693}],
#   [{'label': 'neutral', 'score': 0.6479063630104065}],
#   [{'label': 'neutral', 'score': 0.7690725326538086}],
#   [{'label': 'neutral', 'score': 0.8041695952415466}],
#   [{'label': 'neutral', 'score': 0.7614007592201233}],
#   [{'label': 'neutral', 'score': 0.8376384377479553}],
#   [{'label': 'neutral', 'score': 0.8275958299636841}],
#   [{'label': 'neutral', 'score': 0.8769205808639526}],
#   [{'label': 'neutral', 'score': 0.807134747505188}],
#   [{'label': 'neutral', 'score': 0.8160146474838257}],
#   [{'label': 'neutral', 'score': 0.8357638120651245}],
#   [{'label': 'neutral', 'score': 0.800690770149231}],
#   [{'label': 'neutral', 'score': 0.8129494190216064}],
#   [{'label': 'neutral', 'score': 0.8025028705596924}],
#   [{'label': 'neutral', 'score': 0.8309985399246216}],
#   [{'label': 'neutral', 'score': 0.8882902264595032}],
#   [{'label': 'neutral', 'score': 0.8480954766273499}],
#   [{'label': 'neutral', 'score': 0.8106991648674011}],
#   [{'label': 'neutral', 'score': 0.7881714701652527}],
#   [{'label': 'neutral', 'score': 0.7803605198860168}],
#   [{'label': 'neutral', 'score': 0.7892550826072693}],
#   [{'label': 'neutral', 'score': 0.8055578470230103}],
#   [{'label': 'neutral', 'score': 0.8336710333824158}],
#   [{'label': 'neutral', 'score': 0.8058116436004639}],
#   [{'label': 'neutral', 'score': 0.8107138872146606}],
#   [{'label': 'neutral', 'score': 0.7844944000244141}],
#   [{'label': 'neutral', 'score': 0.8030075430870056}],
#   [{'label': 'neutral', 'score': 0.8144633173942566}],
#   [{'label': 'neutral', 'score': 0.8824824094772339}],
#   [{'label': 'neutral', 'score': 0.7848365902900696}],
#   [{'label': 'neutral', 'score': 0.870326042175293}],
#   [{'label': 'neutral', 'score': 0.8211124539375305}],
#   [{'label': 'neutral', 'score': 0.8101381659507751}],
#   [{'label': 'neutral', 'score': 0.8028321266174316}],
#   [{'label': 'neutral', 'score': 0.7711429595947266}],
#   [{'label': 'neutral', 'score': 0.7612428665161133}],
#   [{'label': 'neutral', 'score': 0.7727997899055481}],
#   [{'label': 'neutral', 'score': 0.8251286745071411}],
#   [{'label': 'neutral', 'score': 0.7889843583106995}],
#   [{'label': 'neutral', 'score': 0.818329393863678}],
#   [{'label': 'neutral', 'score': 0.7975690364837646}],
#   [{'label': 'neutral', 'score': 0.8517048358917236}],
#   [{'label': 'neutral', 'score': 0.8160832524299622}],
#   [{'label': 'neutral', 'score': 0.8420765995979309}],
#   [{'label': 'neutral', 'score': 0.7728337049484253}],
#   [{'label': 'neutral', 'score': 0.8265846371650696}],
#   [{'label': 'positive', 'score': 0.7940300107002258}],
#   [{'label': 'neutral', 'score': 0.7927812337875366}],
#   [{'label': 'neutral', 'score': 0.8332170844078064}],
#   [{'label': 'neutral', 'score': 0.7948427796363831}],
#   [{'label': 'neutral', 'score': 0.9070121645927429}],
#   [{'label': 'neutral', 'score': 0.8046557903289795}],
#   [{'label': 'neutral', 'score': 0.8301842212677002}],
#   [{'label': 'neutral', 'score': 0.7773363590240479}],
#   [{'label': 'neutral', 'score': 0.8669641613960266}],
#   [{'label': 'neutral', 'score': 0.7983652949333191}],
#   [{'label': 'neutral', 'score': 0.7858008742332458}],
#   [{'label': 'neutral', 'score': 0.7851077914237976}],
#   [{'label': 'neutral', 'score': 0.821476936340332}],
#   [{'label': 'neutral', 'score': 0.8104251027107239}],
#   [{'label': 'neutral', 'score': 0.8186704516410828}],
#   [{'label': 'neutral', 'score': 0.8159031867980957}],
#   [{'label': 'neutral', 'score': 0.8242095112800598}],
#   [{'label': 'neutral', 'score': 0.7493965029716492}],
#   [{'label': 'neutral', 'score': 0.8110741376876831}],
#   [{'label': 'neutral', 'score': 0.8534663319587708}],
#   [{'label': 'neutral', 'score': 0.8219298720359802}],
#   [{'label': 'neutral', 'score': 0.8178223967552185}],
#   [{'label': 'neutral', 'score': 0.8577397465705872}],
#   [{'label': 'negative', 'score': 0.5276193022727966}],
#   [{'label': 'neutral', 'score': 0.7944394946098328}],
#   [{'label': 'neutral', 'score': 0.8513050079345703}],
#   [{'label': 'neutral', 'score': 0.8138538599014282}],
#   [{'label': 'neutral', 'score': 0.7854191660881042}],
#   [{'label': 'neutral', 'score': 0.8028358817100525}],
#   [{'label': 'neutral', 'score': 0.7886603474617004}],
#   [{'label': 'neutral', 'score': 0.805000364780426}],
#   [{'label': 'neutral', 'score': 0.819273054599762}],
#   [{'label': 'neutral', 'score': 0.892055869102478}],
#   [{'label': 'neutral', 'score': 0.7932426929473877}],
#   [{'label': 'neutral', 'score': 0.7957188487052917}],
#   [{'label': 'neutral', 'score': 0.8447315096855164}],
#   [{'label': 'neutral', 'score': 0.8207509517669678}],
#   [{'label': 'neutral', 'score': 0.8065499067306519}],
#   [{'label': 'neutral', 'score': 0.7665285468101501}],
#   [{'label': 'neutral', 'score': 0.846894383430481}],
#   [{'label': 'neutral', 'score': 0.8033381700515747}],
#   [{'label': 'neutral', 'score': 0.8118186593055725}],
#   [{'label': 'neutral', 'score': 0.7987297177314758}],
#   [{'label': 'neutral', 'score': 0.8597339987754822}],
#   [{'label': 'neutral', 'score': 0.8094604015350342}],
#   [{'label': 'neutral', 'score': 0.7987516522407532}],
#   [{'label': 'neutral', 'score': 0.8102604150772095}],
#   [{'label': 'neutral', 'score': 0.8465599417686462}],
#   [{'label': 'neutral', 'score': 0.8031777143478394}],
#   [{'label': 'neutral', 'score': 0.801192581653595}],
#   [{'label': 'neutral', 'score': 0.7795376777648926}],
#   [{'label': 'neutral', 'score': 0.862245500087738}],
#   [{'label': 'neutral', 'score': 0.8231136202812195}],
#   [{'label': 'neutral', 'score': 0.8569822907447815}],
#   [{'label': 'neutral', 'score': 0.8626301288604736}],
#   [{'label': 'neutral', 'score': 0.8172221183776855}],
#   [{'label': 'neutral', 'score': 0.8178143501281738}],
#   [{'label': 'neutral', 'score': 0.8007424473762512}],
#   [{'label': 'neutral', 'score': 0.7797955274581909}],
#   [{'label': 'neutral', 'score': 0.8244585990905762}],
#   [{'label': 'neutral', 'score': 0.7885146737098694}],
#   [{'label': 'neutral', 'score': 0.7912161946296692}],
#   [{'label': 'neutral', 'score': 0.822007417678833}],
#   [{'label': 'neutral', 'score': 0.8099378943443298}],
#   [{'label': 'neutral', 'score': 0.7689808011054993}],
#   [{'label': 'neutral', 'score': 0.7179911732673645}],
#   [{'label': 'neutral', 'score': 0.7733104228973389}],
#   [{'label': 'neutral', 'score': 0.6554141044616699}],
#   [{'label': 'neutral', 'score': 0.9054921865463257}],
#   [{'label': 'neutral', 'score': 0.7986020445823669}],
#   [{'label': 'neutral', 'score': 0.8184203505516052}],
#   [{'label': 'neutral', 'score': 0.7853147387504578}],
#   [{'label': 'neutral', 'score': 0.7288632392883301}],
#   [{'label': 'neutral', 'score': 0.8156111240386963}],
#   [{'label': 'neutral', 'score': 0.7956893444061279}],
#   [{'label': 'neutral', 'score': 0.8311696648597717}],
#   [{'label': 'neutral', 'score': 0.8507457971572876}],
#   [{'label': 'neutral', 'score': 0.8379579186439514}],
#   [{'label': 'neutral', 'score': 0.7965162396430969}],
#   [{'label': 'neutral', 'score': 0.8784818053245544}],
#   [{'label': 'neutral', 'score': 0.7947955131530762}],
#   [{'label': 'neutral', 'score': 0.7950319051742554}],
#   [{'label': 'neutral', 'score': 0.7991979718208313}],
#   [{'label': 'neutral', 'score': 0.8348078727722168}],
#   [{'label': 'neutral', 'score': 0.8247318267822266}],
#   [{'label': 'neutral', 'score': 0.8446542620658875}],
#   [{'label': 'neutral', 'score': 0.8133313655853271}],
#   [{'label': 'neutral', 'score': 0.8055651783943176}],
#   [{'label': 'neutral', 'score': 0.8157888054847717}],
#   [{'label': 'neutral', 'score': 0.7642843723297119}],
#   [{'label': 'neutral', 'score': 0.8283776044845581}],
#   [{'label': 'neutral', 'score': 0.8070506453514099}],
#   [{'label': 'neutral', 'score': 0.8185549378395081}],
#   [{'label': 'neutral', 'score': 0.7938528656959534}],
#   [{'label': 'neutral', 'score': 0.8506886959075928}],
#   [{'label': 'neutral', 'score': 0.828278124332428}],
#   [{'label': 'neutral', 'score': 0.8110641837120056}],
#   [{'label': 'neutral', 'score': 0.8438975811004639}],
#   [{'label': 'neutral', 'score': 0.8010031580924988}],
#   [{'label': 'neutral', 'score': 0.799464225769043}],
#   [{'label': 'neutral', 'score': 0.7796317338943481}],
#   [{'label': 'neutral', 'score': 0.7839998006820679}],
#   [{'label': 'neutral', 'score': 0.8241456151008606}],
#   [{'label': 'neutral', 'score': 0.8048562407493591}],
#   [{'label': 'neutral', 'score': 0.808716356754303}],
#   [{'label': 'neutral', 'score': 0.7169083952903748}],
#   [{'label': 'neutral', 'score': 0.796089231967926}],
#   [{'label': 'neutral', 'score': 0.8324378728866577}],
#   [{'label': 'neutral', 'score': 0.7878908514976501}],
#   [{'label': 'neutral', 'score': 0.8615388870239258}],
#   [{'label': 'neutral', 'score': 0.8314393758773804}],
#   [{'label': 'neutral', 'score': 0.7442851066589355}],
#   [{'label': 'neutral', 'score': 0.8347176909446716}],
#   [{'label': 'neutral', 'score': 0.813147783279419}],
#   [{'label': 'neutral', 'score': 0.8452454209327698}],
#   [{'label': 'neutral', 'score': 0.8097119927406311}],
#   [{'label': 'neutral', 'score': 0.7794356346130371}],
#   [{'label': 'neutral', 'score': 0.7639889121055603}],
#   [{'label': 'neutral', 'score': 0.8122709393501282}],
#   [{'label': 'neutral', 'score': 0.7889633774757385}],
#   [{'label': 'neutral', 'score': 0.787326991558075}],
#   [{'label': 'neutral', 'score': 0.769504725933075}],
#   [{'label': 'neutral', 'score': 0.842671275138855}],
#   [{'label': 'neutral', 'score': 0.7809757590293884}],
#   [{'label': 'neutral', 'score': 0.7906164526939392}],
#   [{'label': 'neutral', 'score': 0.8060778379440308}],
#   [{'label': 'neutral', 'score': 0.795159637928009}],
#   [{'label': 'neutral', 'score': 0.8345127105712891}],
#   [{'label': 'neutral', 'score': 0.7268345355987549}],
#   [{'label': 'neutral', 'score': 0.8162474632263184}],
#   [{'label': 'neutral', 'score': 0.8250999450683594}],
#   [{'label': 'neutral', 'score': 0.8073803782463074}],
#   [{'label': 'neutral', 'score': 0.7152645587921143}],
#   [{'label': 'neutral', 'score': 0.8474022150039673}],
#   [{'label': 'neutral', 'score': 0.8309717178344727}],
#   [{'label': 'neutral', 'score': 0.8511613607406616}],
#   [{'label': 'neutral', 'score': 0.8131023645401001}],
#   [{'label': 'neutral', 'score': 0.8151388764381409}],
#   [{'label': 'neutral', 'score': 0.7812162637710571}],
#   [{'label': 'neutral', 'score': 0.8485747575759888}],
#   [{'label': 'neutral', 'score': 0.7752463221549988}],
#   [{'label': 'neutral', 'score': 0.7689917683601379}],
#   [{'label': 'neutral', 'score': 0.8202923536300659}],
#   [{'label': 'neutral', 'score': 0.7923051118850708}],
#   [{'label': 'neutral', 'score': 0.8047060966491699}],
#   [{'label': 'neutral', 'score': 0.792090117931366}],
#   [{'label': 'neutral', 'score': 0.8241615295410156}],
#   [{'label': 'neutral', 'score': 0.8093637228012085}],
#   [{'label': 'neutral', 'score': 0.758295476436615}],
#   [{'label': 'neutral', 'score': 0.735066294670105}],
#   [{'label': 'neutral', 'score': 0.8175428509712219}],
#   [{'label': 'neutral', 'score': 0.8251596093177795}],
#   [{'label': 'neutral', 'score': 0.8081958889961243}],
#   [{'label': 'neutral', 'score': 0.8066773414611816}],
#   [{'label': 'neutral', 'score': 0.8042960166931152}],
#   [{'label': 'neutral', 'score': 0.7891631722450256}],
#   [{'label': 'neutral', 'score': 0.8475831747055054}],
#   [{'label': 'neutral', 'score': 0.8113666772842407}],
#   [{'label': 'neutral', 'score': 0.7910431027412415}],
#   [{'label': 'neutral', 'score': 0.8554927110671997}],
#   [{'label': 'neutral', 'score': 0.8520335555076599}],
#   [{'label': 'neutral', 'score': 0.8121463656425476}],
#   [{'label': 'neutral', 'score': 0.6927779316902161}],
#   [{'label': 'neutral', 'score': 0.6818936467170715}],
#   [{'label': 'neutral', 'score': 0.8399215936660767}],
#   [{'label': 'neutral', 'score': 0.854697048664093}],
#   [{'label': 'neutral', 'score': 0.8011881113052368}],
#   [{'label': 'neutral', 'score': 0.8462724685668945}],
#   [{'label': 'neutral', 'score': 0.7878480553627014}],
#   [{'label': 'neutral', 'score': 0.7902117967605591}],
#   [{'label': 'neutral', 'score': 0.7928011417388916}],
#   [{'label': 'neutral', 'score': 0.7875556945800781}],
#   [{'label': 'neutral', 'score': 0.7801737785339355}],
#   [{'label': 'neutral', 'score': 0.8034146428108215}],
#   [{'label': 'neutral', 'score': 0.8482331037521362}],
#   [{'label': 'neutral', 'score': 0.8213849067687988}],
#   [{'label': 'neutral', 'score': 0.8265570998191833}],
#   [{'label': 'neutral', 'score': 0.8450061678886414}],
#   [{'label': 'neutral', 'score': 0.8747161030769348}],
#   [{'label': 'neutral', 'score': 0.8553408980369568}],
#   [{'label': 'neutral', 'score': 0.8206889629364014}],
#   [{'label': 'neutral', 'score': 0.7854106426239014}],
#   [{'label': 'neutral', 'score': 0.8232360482215881}],
#   [{'label': 'neutral', 'score': 0.8594454526901245}],
#   [{'label': 'neutral', 'score': 0.8044153451919556}],
#   [{'label': 'neutral', 'score': 0.8039876818656921}],
#   [{'label': 'neutral', 'score': 0.8340319991111755}],
#   [{'label': 'neutral', 'score': 0.9030309915542603}],
#   [{'label': 'neutral', 'score': 0.795035183429718}],
#   [{'label': 'neutral', 'score': 0.852533757686615}],
#   [{'label': 'neutral', 'score': 0.8186187148094177}],
#   [{'label': 'neutral', 'score': 0.8060563206672668}],
#   [{'label': 'neutral', 'score': 0.8184488415718079}],
#   [{'label': 'neutral', 'score': 0.7902883887290955}],
#   [{'label': 'neutral', 'score': 0.9116520285606384}],
#   [{'label': 'neutral', 'score': 0.80300372838974}],
#   [{'label': 'neutral', 'score': 0.8219477534294128}],
#   [{'label': 'neutral', 'score': 0.9170721769332886}],
#   [{'label': 'neutral', 'score': 0.810752809047699}],
#   [{'label': 'neutral', 'score': 0.8246296048164368}],
#   [{'label': 'neutral', 'score': 0.8150969743728638}],
#   [{'label': 'neutral', 'score': 0.8343458771705627}],
#   [{'label': 'neutral', 'score': 0.7873018383979797}],
#   [{'label': 'neutral', 'score': 0.8386403322219849}],
#   [{'label': 'neutral', 'score': 0.7734971642494202}],
#   [{'label': 'neutral', 'score': 0.8463850021362305}],
#   [{'label': 'neutral', 'score': 0.8423958420753479}],
#   [{'label': 'neutral', 'score': 0.820271909236908}],
#   [{'label': 'neutral', 'score': 0.8481174111366272}],
#   [{'label': 'neutral', 'score': 0.8113639950752258}],
#   [{'label': 'neutral', 'score': 0.807543933391571}],
#   [{'label': 'neutral', 'score': 0.8394923210144043}],
#   [{'label': 'neutral', 'score': 0.8061392307281494}],
#   [{'label': 'neutral', 'score': 0.8081574440002441}],
#   [{'label': 'neutral', 'score': 0.8972548842430115}],
#   [{'label': 'neutral', 'score': 0.8745504021644592}],
#   [{'label': 'neutral', 'score': 0.8466287851333618}],
#   [{'label': 'neutral', 'score': 0.8307403922080994}],
#   [{'label': 'neutral', 'score': 0.7909809947013855}],
#   [{'label': 'neutral', 'score': 0.7851885557174683}],
#   [{'label': 'neutral', 'score': 0.8070052266120911}],
#   [{'label': 'neutral', 'score': 0.8543300032615662}],
#   [{'label': 'neutral', 'score': 0.8325074315071106}],
#   [{'label': 'neutral', 'score': 0.8693332672119141}],
#   [{'label': 'neutral', 'score': 0.791888952255249}],
#   [{'label': 'neutral', 'score': 0.8563300967216492}],
#   [{'label': 'neutral', 'score': 0.8194010853767395}],
#   [{'label': 'neutral', 'score': 0.8950945138931274}],
#   [{'label': 'neutral', 'score': 0.8044971227645874}],
#   [{'label': 'neutral', 'score': 0.816792368888855}],
#   [{'label': 'neutral', 'score': 0.8400626182556152}],
#   [{'label': 'neutral', 'score': 0.8018448352813721}],
#   [{'label': 'neutral', 'score': 0.820846438407898}],
#   [{'label': 'neutral', 'score': 0.8315771222114563}],
#   [{'label': 'neutral', 'score': 0.7971557378768921}],
#   [{'label': 'neutral', 'score': 0.8613263368606567}],
#   [{'label': 'neutral', 'score': 0.8522216081619263}],
#   [{'label': 'neutral', 'score': 0.8496499061584473}],
#   [{'label': 'neutral', 'score': 0.7737569808959961}],
#   [{'label': 'neutral', 'score': 0.8125612139701843}],
#   [{'label': 'neutral', 'score': 0.8240885138511658}],
#   [{'label': 'neutral', 'score': 0.7951064109802246}],
#   [{'label': 'neutral', 'score': 0.8485199213027954}],
#   [{'label': 'neutral', 'score': 0.7853989601135254}],
#   [{'label': 'neutral', 'score': 0.8417856097221375}],
#   [{'label': 'neutral', 'score': 0.8314006328582764}],
#   [{'label': 'neutral', 'score': 0.8731293082237244}],
#   [{'label': 'neutral', 'score': 0.7984173893928528}],
#   [{'label': 'neutral', 'score': 0.8101924657821655}],
#   [{'label': 'neutral', 'score': 0.7168542146682739}],
#   [{'label': 'neutral', 'score': 0.8111101984977722}],
#   [{'label': 'neutral', 'score': 0.8231449127197266}],
#   [{'label': 'neutral', 'score': 0.7882822751998901}],
#   [{'label': 'neutral', 'score': 0.8058017492294312}],
#   [{'label': 'neutral', 'score': 0.8310279250144958}],
#   [{'label': 'neutral', 'score': 0.8042827248573303}],
#   [{'label': 'neutral', 'score': 0.6757005453109741}],
#   [{'label': 'neutral', 'score': 0.8064939975738525}],
#   [{'label': 'neutral', 'score': 0.8136894106864929}],
#   [{'label': 'neutral', 'score': 0.7843466401100159}],
#   [{'label': 'neutral', 'score': 0.8072342276573181}],
#   [{'label': 'neutral', 'score': 0.8156201839447021}],
#   [{'label': 'neutral', 'score': 0.851064920425415}],
#   [{'label': 'neutral', 'score': 0.8157532811164856}],
#   [{'label': 'neutral', 'score': 0.8850409984588623}],
#   [{'label': 'neutral', 'score': 0.834966242313385}],
#   [{'label': 'neutral', 'score': 0.714235782623291}],
#   [{'label': 'neutral', 'score': 0.865028440952301}],
#   [{'label': 'neutral', 'score': 0.8174556493759155}],
#   [{'label': 'neutral', 'score': 0.887172281742096}],
#   [{'label': 'neutral', 'score': 0.7766032218933105}],
#   [{'label': 'neutral', 'score': 0.7038737535476685}],
#   [{'label': 'neutral', 'score': 0.7587065100669861}],
#   [{'label': 'neutral', 'score': 0.832391619682312}],
#   [{'label': 'neutral', 'score': 0.8034906387329102}],
#   [{'label': 'neutral', 'score': 0.7934871315956116}],
#   [{'label': 'neutral', 'score': 0.746092677116394}],
#   [{'label': 'neutral', 'score': 0.7897807955741882}],
#   [{'label': 'neutral', 'score': 0.8498783111572266}],
#   [{'label': 'neutral', 'score': 0.8215965032577515}],
#   [{'label': 'neutral', 'score': 0.8033043146133423}],
#   [{'label': 'neutral', 'score': 0.7645899057388306}],
#   [{'label': 'neutral', 'score': 0.8189488053321838}],
#   [{'label': 'neutral', 'score': 0.8360038995742798}],
#   [{'label': 'neutral', 'score': 0.8026938438415527}],
#   [{'label': 'neutral', 'score': 0.8570548892021179}],
#   [{'label': 'neutral', 'score': 0.8372963070869446}],
#   [{'label': 'neutral', 'score': 0.8683032393455505}],
#   [{'label': 'neutral', 'score': 0.8078295588493347}],
#   [{'label': 'neutral', 'score': 0.8192509412765503}],
#   [{'label': 'neutral', 'score': 0.776850163936615}],
#   [{'label': 'neutral', 'score': 0.8410994410514832}],
#   [{'label': 'neutral', 'score': 0.7890602350234985}],
#   [{'label': 'neutral', 'score': 0.7065728902816772}],
#   [{'label': 'neutral', 'score': 0.8133262395858765}],
#   [{'label': 'neutral', 'score': 0.7847557663917542}],
#   [{'label': 'neutral', 'score': 0.72725909948349}],
#   [{'label': 'neutral', 'score': 0.6737416386604309}],
#   [{'label': 'neutral', 'score': 0.8068585991859436}],
#   [{'label': 'neutral', 'score': 0.7755662798881531}],
#   [{'label': 'neutral', 'score': 0.8123542666435242}],
#   [{'label': 'neutral', 'score': 0.8089421391487122}],
#   [{'label': 'neutral', 'score': 0.7450803518295288}],
#   [{'label': 'neutral', 'score': 0.7885047793388367}],
#   [{'label': 'neutral', 'score': 0.7435312867164612}],
#   [{'label': 'neutral', 'score': 0.8358186483383179}],
#   [{'label': 'neutral', 'score': 0.7932491898536682}],
#   [{'label': 'neutral', 'score': 0.7853496670722961}],
#   [{'label': 'neutral', 'score': 0.7883107662200928}],
#   [{'label': 'neutral', 'score': 0.8019956946372986}],
#   [{'label': 'neutral', 'score': 0.7736228704452515}],
#   [{'label': 'neutral', 'score': 0.8115883469581604}],
#   [{'label': 'neutral', 'score': 0.8207902908325195}],
#   [{'label': 'neutral', 'score': 0.7350926995277405}],
#   [{'label': 'neutral', 'score': 0.8333714604377747}],
#   [{'label': 'neutral', 'score': 0.7196052074432373}],
#   [{'label': 'neutral', 'score': 0.8443644642829895}],
#   [{'label': 'neutral', 'score': 0.8079620003700256}],
#   [{'label': 'neutral', 'score': 0.8004617691040039}],
#   [{'label': 'neutral', 'score': 0.790692925453186}],
#   [{'label': 'neutral', 'score': 0.8381924033164978}],
#   [{'label': 'neutral', 'score': 0.6780502200126648}],
#   [{'label': 'neutral', 'score': 0.8063266277313232}],
#   [{'label': 'neutral', 'score': 0.8042283654212952}],
#   [{'label': 'neutral', 'score': 0.8305249810218811}],
#   [{'label': 'neutral', 'score': 0.6978712677955627}],
#   [{'label': 'neutral', 'score': 0.8270843029022217}],
#   [{'label': 'neutral', 'score': 0.8439555764198303}],
#   [{'label': 'neutral', 'score': 0.8113567233085632}],
#   [{'label': 'neutral', 'score': 0.7898111343383789}],
#   [{'label': 'neutral', 'score': 0.8170567154884338}],
#   [{'label': 'neutral', 'score': 0.7869150638580322}],
#   [{'label': 'neutral', 'score': 0.7627661228179932}],
#   [{'label': 'neutral', 'score': 0.7985985279083252}],
#   [{'label': 'neutral', 'score': 0.7858253121376038}],
#   [{'label': 'neutral', 'score': 0.9106699228286743}],
#   [{'label': 'neutral', 'score': 0.9020178318023682}],
#   [{'label': 'neutral', 'score': 0.7863823771476746}],
#   [{'label': 'neutral', 'score': 0.8186014890670776}],
#   [{'label': 'neutral', 'score': 0.7674838900566101}],
#   [{'label': 'neutral', 'score': 0.7965378165245056}],
#   [{'label': 'neutral', 'score': 0.7911136150360107}],
#   [{'label': 'neutral', 'score': 0.8368545174598694}],
#   [{'label': 'neutral', 'score': 0.6718405485153198}],
#   [{'label': 'neutral', 'score': 0.7908468842506409}],
#   [{'label': 'neutral', 'score': 0.8363258838653564}],
#   [{'label': 'neutral', 'score': 0.845199465751648}],
#   [{'label': 'neutral', 'score': 0.8067885637283325}],
#   [{'label': 'neutral', 'score': 0.7979077696800232}],
#   [{'label': 'neutral', 'score': 0.8290682435035706}],
#   [{'label': 'neutral', 'score': 0.820443868637085}],
#   [{'label': 'neutral', 'score': 0.8110151886940002}],
#   [{'label': 'neutral', 'score': 0.7960912585258484}],
#   [{'label': 'neutral', 'score': 0.8144909739494324}],
#   [{'label': 'neutral', 'score': 0.8655691742897034}],
#   [{'label': 'neutral', 'score': 0.7961028218269348}],
#   [{'label': 'neutral', 'score': 0.8443647027015686}],
#   [{'label': 'neutral', 'score': 0.7848917841911316}],
#   [{'label': 'neutral', 'score': 0.7310305833816528}],
#   [{'label': 'neutral', 'score': 0.8525452017784119}],
#   [{'label': 'neutral', 'score': 0.862786591053009}],
#   [{'label': 'neutral', 'score': 0.8607044219970703}],
#   [{'label': 'neutral', 'score': 0.7335430979728699}],
#   [{'label': 'neutral', 'score': 0.870949387550354}],
#   [{'label': 'neutral', 'score': 0.7662453651428223}],
#   [{'label': 'neutral', 'score': 0.7645584940910339}],
#   [{'label': 'neutral', 'score': 0.828902542591095}],
#   [{'label': 'neutral', 'score': 0.7605218887329102}],
#   [{'label': 'neutral', 'score': 0.8423328995704651}],
#   [{'label': 'neutral', 'score': 0.8290673494338989}],
#   [{'label': 'neutral', 'score': 0.803094208240509}],
#   [{'label': 'neutral', 'score': 0.8072006702423096}],
#   [{'label': 'neutral', 'score': 0.8456933498382568}],
#   [{'label': 'neutral', 'score': 0.8051064610481262}],
#   [{'label': 'neutral', 'score': 0.8071939945220947}],
#   [{'label': 'neutral', 'score': 0.8486436009407043}],
#   [{'label': 'neutral', 'score': 0.7610369324684143}],
#   [{'label': 'neutral', 'score': 0.7650768160820007}],
#   [{'label': 'neutral', 'score': 0.828700840473175}],
#   [{'label': 'neutral', 'score': 0.8616635203361511}],
#   [{'label': 'neutral', 'score': 0.8226791024208069}],
#   [{'label': 'neutral', 'score': 0.8233374953269958}],
#   [{'label': 'neutral', 'score': 0.5902503728866577}],
#   [{'label': 'neutral', 'score': 0.7771623730659485}],
#   [{'label': 'neutral', 'score': 0.8007469773292542}],
#   [{'label': 'neutral', 'score': 0.801690936088562}],
#   [{'label': 'neutral', 'score': 0.7977827191352844}],
#   [{'label': 'neutral', 'score': 0.8438344597816467}],
#   [{'label': 'neutral', 'score': 0.7653519511222839}],
#   [{'label': 'neutral', 'score': 0.7907150983810425}],
#   [{'label': 'neutral', 'score': 0.8495519757270813}],
#   [{'label': 'neutral', 'score': 0.7822535634040833}],
#   [{'label': 'neutral', 'score': 0.6219704151153564}],
#   [{'label': 'neutral', 'score': 0.8053629994392395}],
#   [{'label': 'neutral', 'score': 0.8358368277549744}],
#   [{'label': 'neutral', 'score': 0.8155771493911743}],
#   [{'label': 'neutral', 'score': 0.8564454317092896}],
#   [{'label': 'neutral', 'score': 0.7933364510536194}],
#   [{'label': 'neutral', 'score': 0.8870040774345398}],
#   [{'label': 'neutral', 'score': 0.8244214057922363}],
#   [{'label': 'neutral', 'score': 0.7612928748130798}],
#   [{'label': 'neutral', 'score': 0.8290802836418152}],
#   [{'label': 'neutral', 'score': 0.8474379777908325}],
#   [{'label': 'neutral', 'score': 0.805435061454773}],
#   [{'label': 'neutral', 'score': 0.8347805738449097}],
#   [{'label': 'neutral', 'score': 0.8744121193885803}],
#   [{'label': 'neutral', 'score': 0.7933201193809509}],
#   [{'label': 'neutral', 'score': 0.8086094260215759}],
#   [{'label': 'neutral', 'score': 0.7675222158432007}],
#   [{'label': 'neutral', 'score': 0.8162973523139954}],
#   [{'label': 'neutral', 'score': 0.808715283870697}],
#   [{'label': 'neutral', 'score': 0.7970499396324158}],
#   [{'label': 'neutral', 'score': 0.9007775187492371}],
# ...
#   [{'label': 'neutral', 'score': 0.9993985891342163}],
#   [{'label': 'neutral', 'score': 0.9997546076774597}],
#   [{'label': 'neutral', 'score': 0.9995970129966736}],
#   [{'label': 'neutral', 'score': 0.9995906949043274}],
#   [{'label': 'neutral', 'score': 0.9991698265075684}],
#   [{'label': 'neutral', 'score': 0.9995404481887817}],
#   [{'label': 'neutral', 'score': 0.9997647404670715}],
#   [{'label': 'neutral', 'score': 0.9996657371520996}],
#   [{'label': 'neutral', 'score': 0.9992495179176331}],
#   [{'label': 'neutral', 'score': 0.9996871948242188}],
#   [{'label': 'neutral', 'score': 0.9995852112770081}],
#   [{'label': 'neutral', 'score': 0.9996172189712524}],
#   [{'label': 'neutral', 'score': 0.9996213912963867}],
#   [{'label': 'neutral', 'score': 0.9993705153465271}],
#   [{'label': 'neutral', 'score': 0.9998321533203125}],
#   [{'label': 'neutral', 'score': 0.9992758631706238}],
#   [{'label': 'neutral', 'score': 0.9996669292449951}],
#   [{'label': 'neutral', 'score': 0.9998295307159424}],
#   [{'label': 'neutral', 'score': 0.9995707869529724}],
#   [{'label': 'neutral', 'score': 0.9997219443321228}],
#   [{'label': 'neutral', 'score': 0.9996225833892822}],
#   [{'label': 'neutral', 'score': 0.9995273351669312}],
#   [{'label': 'neutral', 'score': 0.9996793270111084}],
#   [{'label': 'neutral', 'score': 0.9997346997261047}],
#   [{'label': 'neutral', 'score': 0.999031662940979}],
#   [{'label': 'neutral', 'score': 0.9996755123138428}],
#   [{'label': 'neutral', 'score': 0.9993041753768921}],
#   [{'label': 'neutral', 'score': 0.9996434450149536}],
#   [{'label': 'neutral', 'score': 0.9996864795684814}],
#   [{'label': 'neutral', 'score': 0.9994370341300964}],
#   [{'label': 'neutral', 'score': 0.9997205138206482}],
#   [{'label': 'neutral', 'score': 0.9993574023246765}],
#   [{'label': 'neutral', 'score': 0.9996360540390015}],
#   [{'label': 'neutral', 'score': 0.9996496438980103}],
#   [{'label': 'neutral', 'score': 0.9997919201850891}],
#   [{'label': 'neutral', 'score': 0.9995492100715637}],
#   [{'label': 'neutral', 'score': 0.9995891451835632}],
#   [{'label': 'neutral', 'score': 0.9996819496154785}],
#   [{'label': 'neutral', 'score': 0.9997164607048035}],
#   [{'label': 'neutral', 'score': 0.9996275901794434}],
#   [{'label': 'neutral', 'score': 0.9996621608734131}],
#   [{'label': 'neutral', 'score': 0.9997772574424744}],
#   [{'label': 'neutral', 'score': 0.9995806813240051}],
#   [{'label': 'neutral', 'score': 0.9997045397758484}],
#   [{'label': 'neutral', 'score': 0.9995154142379761}],
#   [{'label': 'neutral', 'score': 0.9997478127479553}],
#   [{'label': 'neutral', 'score': 0.9994930028915405}],
#   [{'label': 'neutral', 'score': 0.9995668530464172}],
#   [{'label': 'neutral', 'score': 0.9996542930603027}],
#   [{'label': 'neutral', 'score': 0.9996657371520996}],
#   [{'label': 'neutral', 'score': 0.9997389912605286}],
#   [{'label': 'neutral', 'score': 0.9996156692504883}],
#   [{'label': 'neutral', 'score': 0.9993922710418701}],
#   [{'label': 'neutral', 'score': 0.9995300769805908}],
#   [{'label': 'neutral', 'score': 0.9995774626731873}],
#   [{'label': 'neutral', 'score': 0.9996789693832397}],
#   [{'label': 'neutral', 'score': 0.9996032118797302}],
#   [{'label': 'neutral', 'score': 0.9997099041938782}],
#   [{'label': 'neutral', 'score': 0.9993361830711365}],
#   [{'label': 'neutral', 'score': 0.9998168349266052}],
#   [{'label': 'neutral', 'score': 0.9992122650146484}],
#   [{'label': 'neutral', 'score': 0.9992148876190186}],
#   [{'label': 'neutral', 'score': 0.9997757077217102}],
#   [{'label': 'neutral', 'score': 0.9995419979095459}],
#   [{'label': 'neutral', 'score': 0.9992881417274475}],
#   [{'label': 'neutral', 'score': 0.9994933605194092}],
#   [{'label': 'neutral', 'score': 0.9995606541633606}],
#   [{'label': 'neutral', 'score': 0.9995768666267395}],
#   [{'label': 'neutral', 'score': 0.9994250535964966}],
#   [{'label': 'neutral', 'score': 0.9995397329330444}],
#   [{'label': 'neutral', 'score': 0.9992340803146362}],
#   [{'label': 'neutral', 'score': 0.9996623992919922}],
#   [{'label': 'neutral', 'score': 0.9998112320899963}],
#   [{'label': 'neutral', 'score': 0.9996234178543091}],
#   [{'label': 'neutral', 'score': 0.9996463060379028}],
#   [{'label': 'neutral', 'score': 0.9993265867233276}],
#   [{'label': 'neutral', 'score': 0.9994768500328064}],
#   [{'label': 'neutral', 'score': 0.9997773766517639}],
#   [{'label': 'neutral', 'score': 0.9997925162315369}],
#   [{'label': 'neutral', 'score': 0.9995837807655334}],
#   [{'label': 'neutral', 'score': 0.9993734955787659}],
#   [{'label': 'neutral', 'score': 0.999765932559967}],
#   [{'label': 'neutral', 'score': 0.9998043179512024}],
#   [{'label': 'neutral', 'score': 0.9994268417358398}],
#   [{'label': 'neutral', 'score': 0.9997803568840027}],
#   [{'label': 'neutral', 'score': 0.9990886449813843}],
#   [{'label': 'neutral', 'score': 0.9996389150619507}],
#   [{'label': 'neutral', 'score': 0.9996827840805054}],
#   [{'label': 'neutral', 'score': 0.9996086955070496}],
#   [{'label': 'neutral', 'score': 0.9994612336158752}],
#   [{'label': 'neutral', 'score': 0.9997625946998596}],
#   [{'label': 'neutral', 'score': 0.9997342228889465}],
#   [{'label': 'neutral', 'score': 0.999394416809082}],
#   [{'label': 'neutral', 'score': 0.9995582699775696}],
#   [{'label': 'neutral', 'score': 0.9997078776359558}],
#   [{'label': 'neutral', 'score': 0.9995290040969849}],
#   [{'label': 'neutral', 'score': 0.9995158910751343}],
#   [{'label': 'neutral', 'score': 0.9995697140693665}],
#   [{'label': 'neutral', 'score': 0.9997144341468811}],
#   [{'label': 'neutral', 'score': 0.9993016719818115}],
#   [{'label': 'neutral', 'score': 0.9994937181472778}],
#   [{'label': 'neutral', 'score': 0.9997565150260925}],
#   [{'label': 'neutral', 'score': 0.9994007349014282}],
#   [{'label': 'neutral', 'score': 0.9997877478599548}],
#   [{'label': 'neutral', 'score': 0.9996917247772217}],
#   [{'label': 'neutral', 'score': 0.9991078972816467}],
#   [{'label': 'neutral', 'score': 0.9996144771575928}],
#   [{'label': 'neutral', 'score': 0.9996198415756226}],
#   [{'label': 'neutral', 'score': 0.9996746778488159}],
#   [{'label': 'neutral', 'score': 0.99943608045578}],
#   [{'label': 'neutral', 'score': 0.9998182654380798}],
#   [{'label': 'neutral', 'score': 0.9997569918632507}],
#   [{'label': 'neutral', 'score': 0.9997056126594543}],
#   [{'label': 'neutral', 'score': 0.9995645880699158}],
#   [{'label': 'neutral', 'score': 0.9996999502182007}],
#   [{'label': 'neutral', 'score': 0.9996055960655212}],
#   [{'label': 'neutral', 'score': 0.9994794726371765}],
#   [{'label': 'neutral', 'score': 0.9996778964996338}],
#   [{'label': 'neutral', 'score': 0.999599039554596}],
#   [{'label': 'neutral', 'score': 0.9995742440223694}],
#   [{'label': 'neutral', 'score': 0.9997157454490662}],
#   [{'label': 'neutral', 'score': 0.9997105002403259}],
#   [{'label': 'neutral', 'score': 0.9995699524879456}],
#   [{'label': 'neutral', 'score': 0.9996180534362793}],
#   [{'label': 'neutral', 'score': 0.9995715022087097}],
#   [{'label': 'neutral', 'score': 0.9993641972541809}],
#   [{'label': 'neutral', 'score': 0.9993176460266113}],
#   [{'label': 'neutral', 'score': 0.9995189905166626}],
#   [{'label': 'neutral', 'score': 0.9996993541717529}],
#   [{'label': 'neutral', 'score': 0.9994630217552185}],
#   [{'label': 'neutral', 'score': 0.9995021820068359}],
#   [{'label': 'neutral', 'score': 0.9996395111083984}],
#   [{'label': 'neutral', 'score': 0.9995214939117432}],
#   [{'label': 'neutral', 'score': 0.9994200468063354}],
#   [{'label': 'neutral', 'score': 0.999645471572876}],
#   [{'label': 'neutral', 'score': 0.9992157220840454}],
#   [{'label': 'neutral', 'score': 0.9996693134307861}],
#   [{'label': 'neutral', 'score': 0.9992252588272095}],
#   [{'label': 'neutral', 'score': 0.9992867112159729}],
#   [{'label': 'neutral', 'score': 0.99974125623703}],
#   [{'label': 'neutral', 'score': 0.9995817542076111}],
#   [{'label': 'neutral', 'score': 0.9995834231376648}],
#   [{'label': 'neutral', 'score': 0.9997275471687317}],
#   [{'label': 'neutral', 'score': 0.9997503161430359}],
#   [{'label': 'neutral', 'score': 0.9997667670249939}],
#   [{'label': 'neutral', 'score': 0.9996592998504639}],
#   [{'label': 'neutral', 'score': 0.9996194839477539}],
#   [{'label': 'neutral', 'score': 0.9996017813682556}],
#   [{'label': 'neutral', 'score': 0.9996740818023682}],
#   [{'label': 'neutral', 'score': 0.9993754029273987}],
#   [{'label': 'neutral', 'score': 0.9997029900550842}],
#   [{'label': 'neutral', 'score': 0.9997033476829529}],
#   [{'label': 'neutral', 'score': 0.9994008541107178}],
#   [{'label': 'neutral', 'score': 0.9996145963668823}],
#   [{'label': 'neutral', 'score': 0.9994565844535828}],
#   [{'label': 'neutral', 'score': 0.999569833278656}],
#   [{'label': 'neutral', 'score': 0.999675989151001}],
#   [{'label': 'neutral', 'score': 0.9997361302375793}],
#   [{'label': 'neutral', 'score': 0.9997925162315369}],
#   [{'label': 'neutral', 'score': 0.9996954202651978}],
#   [{'label': 'neutral', 'score': 0.999687910079956}],
#   [{'label': 'neutral', 'score': 0.99974125623703}],
#   [{'label': 'neutral', 'score': 0.9995759129524231}],
#   [{'label': 'neutral', 'score': 0.9994221925735474}],
#   [{'label': 'neutral', 'score': 0.9998016953468323}],
#   [{'label': 'neutral', 'score': 0.9996823072433472}],
#   [{'label': 'neutral', 'score': 0.9998192191123962}],
#   [{'label': 'neutral', 'score': 0.9991494417190552}],
#   [{'label': 'neutral', 'score': 0.999344527721405}],
#   [{'label': 'neutral', 'score': 0.9997537732124329}],
#   [{'label': 'neutral', 'score': 0.999524712562561}],
#   [{'label': 'neutral', 'score': 0.9992246627807617}],
#   [{'label': 'neutral', 'score': 0.9995785355567932}],
#   [{'label': 'neutral', 'score': 0.9996864795684814}],
#   [{'label': 'neutral', 'score': 0.9997541308403015}],
#   [{'label': 'neutral', 'score': 0.9997983574867249}],
#   [{'label': 'neutral', 'score': 0.9995166063308716}],
#   [{'label': 'neutral', 'score': 0.9996974468231201}],
#   [{'label': 'neutral', 'score': 0.9996216297149658}],
#   [{'label': 'neutral', 'score': 0.9994551539421082}],
#   [{'label': 'neutral', 'score': 0.9996849298477173}],
#   [{'label': 'neutral', 'score': 0.999521017074585}],
#   [{'label': 'neutral', 'score': 0.9993904829025269}],
#   [{'label': 'neutral', 'score': 0.9996283054351807}],
#   [{'label': 'neutral', 'score': 0.9995493292808533}],
#   [{'label': 'neutral', 'score': 0.999537467956543}],
#   [{'label': 'neutral', 'score': 0.999657392501831}],
#   [{'label': 'neutral', 'score': 0.9991729855537415}],
#   [{'label': 'neutral', 'score': 0.9996685981750488}],
#   [{'label': 'neutral', 'score': 0.9997385144233704}],
#   [{'label': 'neutral', 'score': 0.9994888305664062}],
#   [{'label': 'neutral', 'score': 0.9995365142822266}],
#   [{'label': 'neutral', 'score': 0.9997279047966003}],
#   [{'label': 'neutral', 'score': 0.9997625946998596}],
#   [{'label': 'neutral', 'score': 0.9995266199111938}],
#   [{'label': 'neutral', 'score': 0.9993351101875305}],
#   [{'label': 'neutral', 'score': 0.9993519186973572}],
#   [{'label': 'neutral', 'score': 0.9990288019180298}],
#   [{'label': 'neutral', 'score': 0.9996582269668579}],
#   [{'label': 'neutral', 'score': 0.9995591044425964}],
#   [{'label': 'neutral', 'score': 0.9997535347938538}],
#   [{'label': 'neutral', 'score': 0.9993301630020142}],
#   [{'label': 'neutral', 'score': 0.9996562004089355}],
#   [{'label': 'neutral', 'score': 0.9992479681968689}],
#   [{'label': 'neutral', 'score': 0.9995909333229065}],
#   [{'label': 'neutral', 'score': 0.9997264742851257}],
#   [{'label': 'neutral', 'score': 0.9997486472129822}],
#   [{'label': 'neutral', 'score': 0.999672532081604}],
#   [{'label': 'neutral', 'score': 0.9996302127838135}],
#   [{'label': 'neutral', 'score': 0.9996321201324463}],
#   [{'label': 'neutral', 'score': 0.9992982149124146}],
#   [{'label': 'neutral', 'score': 0.9994733929634094}],
#   [{'label': 'neutral', 'score': 0.9994993209838867}],
#   [{'label': 'neutral', 'score': 0.9996770620346069}],
#   [{'label': 'neutral', 'score': 0.9995496869087219}],
#   [{'label': 'neutral', 'score': 0.999494194984436}],
#   [{'label': 'neutral', 'score': 0.9995715022087097}],
#   [{'label': 'neutral', 'score': 0.9997279047966003}],
#   [{'label': 'neutral', 'score': 0.9992488026618958}],
#   [{'label': 'neutral', 'score': 0.9996531009674072}],
#   [{'label': 'neutral', 'score': 0.9995809197425842}],
#   [{'label': 'neutral', 'score': 0.9997187256813049}],
#   [{'label': 'neutral', 'score': 0.999750554561615}],
#   [{'label': 'neutral', 'score': 0.9995672106742859}],
#   [{'label': 'neutral', 'score': 0.9996523857116699}],
#   [{'label': 'neutral', 'score': 0.9996640682220459}],
#   [{'label': 'neutral', 'score': 0.9995467066764832}],
#   [{'label': 'neutral', 'score': 0.9996745586395264}],
#   [{'label': 'neutral', 'score': 0.999454915523529}],
#   [{'label': 'neutral', 'score': 0.9994657635688782}],
#   [{'label': 'neutral', 'score': 0.9997677206993103}],
#   [{'label': 'neutral', 'score': 0.9994515776634216}],
#   [{'label': 'neutral', 'score': 0.9996353387832642}],
#   [{'label': 'neutral', 'score': 0.9989374279975891}],
#   [{'label': 'neutral', 'score': 0.9995009899139404}],
#   [{'label': 'neutral', 'score': 0.9997550845146179}],
#   [{'label': 'neutral', 'score': 0.9998419284820557}],
#   [{'label': 'neutral', 'score': 0.9994602799415588}],
#   [{'label': 'neutral', 'score': 0.9996205568313599}],
#   [{'label': 'neutral', 'score': 0.9997180104255676}],
#   [{'label': 'neutral', 'score': 0.9996789693832397}],
#   [{'label': 'neutral', 'score': 0.9994240999221802}],
#   [{'label': 'neutral', 'score': 0.9995669722557068}],
#   [{'label': 'neutral', 'score': 0.9995750784873962}],
#   [{'label': 'neutral', 'score': 0.9997528195381165}],
#   [{'label': 'neutral', 'score': 0.9996552467346191}],
#   [{'label': 'neutral', 'score': 0.9997095465660095}],
#   [{'label': 'neutral', 'score': 0.9991983771324158}],
#   [{'label': 'neutral', 'score': 0.9995465874671936}],
#   [{'label': 'neutral', 'score': 0.9997637867927551}],
#   [{'label': 'neutral', 'score': 0.9993159770965576}],
#   [{'label': 'neutral', 'score': 0.9994907379150391}],
#   [{'label': 'neutral', 'score': 0.9995525479316711}],
#   [{'label': 'neutral', 'score': 0.9993501305580139}],
#   [{'label': 'neutral', 'score': 0.9995977282524109}],
#   [{'label': 'neutral', 'score': 0.9994070529937744}],
#   [{'label': 'neutral', 'score': 0.9996676445007324}],
#   [{'label': 'neutral', 'score': 0.9995563626289368}],
#   [{'label': 'neutral', 'score': 0.9993624091148376}],
#   [{'label': 'neutral', 'score': 0.999822199344635}],
#   [{'label': 'neutral', 'score': 0.9993108510971069}],
#   [{'label': 'neutral', 'score': 0.9997795224189758}],
#   [{'label': 'neutral', 'score': 0.9997106194496155}],
#   [{'label': 'neutral', 'score': 0.99959796667099}],
#   [{'label': 'neutral', 'score': 0.9996193647384644}],
#   [{'label': 'neutral', 'score': 0.9997201561927795}],
#   [{'label': 'neutral', 'score': 0.9992437362670898}],
#   [{'label': 'neutral', 'score': 0.9993116855621338}],
#   [{'label': 'neutral', 'score': 0.9995684027671814}],
#   [{'label': 'neutral', 'score': 0.9994826316833496}],
#   [{'label': 'neutral', 'score': 0.9993165731430054}],
#   [{'label': 'neutral', 'score': 0.9995951056480408}],
#   [{'label': 'neutral', 'score': 0.999842643737793}],
#   [{'label': 'neutral', 'score': 0.9992896318435669}],
#   [{'label': 'neutral', 'score': 0.9995711445808411}],
#   [{'label': 'neutral', 'score': 0.999382734298706}],
#   [{'label': 'neutral', 'score': 0.9995930790901184}],
#   [{'label': 'neutral', 'score': 0.9996410608291626}],
#   [{'label': 'neutral', 'score': 0.9994843006134033}],
#   [{'label': 'neutral', 'score': 0.9993178844451904}],
#   [{'label': 'neutral', 'score': 0.9998151659965515}],
#   [{'label': 'neutral', 'score': 0.9995064735412598}],
#   [{'label': 'neutral', 'score': 0.999382495880127}],
#   [{'label': 'neutral', 'score': 0.9992757439613342}],
#   [{'label': 'neutral', 'score': 0.9996806383132935}],
#   [{'label': 'neutral', 'score': 0.9996471405029297}],
#   [{'label': 'neutral', 'score': 0.9997801184654236}],
#   [{'label': 'neutral', 'score': 0.9994045495986938}],
#   [{'label': 'neutral', 'score': 0.9994441866874695}],
#   [{'label': 'neutral', 'score': 0.9997702240943909}],
#   [{'label': 'neutral', 'score': 0.9994593262672424}],
#   ...]}

# %%
financial_phrasebank_results = {
    'twitter_roberta': twitter_roberta.evaluate_dataset(financial_phrasebank, feature='sentence'),
    'financial_news_roberta': financial_news_roberta.evaluate_dataset(financial_phrasebank, feature='sentence')
}

# %%
display(financial_phrasebank_results)
# Out:
# {'twitter_roberta': [[{'label': 'neutral', 'score': 0.8576387763023376}],
#   [{'label': 'neutral', 'score': 0.782501757144928}],
#   [{'label': 'neutral', 'score': 0.7774349451065063}],
#   [{'label': 'neutral', 'score': 0.8919249176979065}],
#   [{'label': 'neutral', 'score': 0.919111430644989}],
#   [{'label': 'neutral', 'score': 0.8051819801330566}],
#   [{'label': 'neutral', 'score': 0.8023940920829773}],
#   [{'label': 'neutral', 'score': 0.8336440324783325}],
#   [{'label': 'neutral', 'score': 0.7885507941246033}],
#   [{'label': 'neutral', 'score': 0.8087793588638306}],
#   [{'label': 'neutral', 'score': 0.8387629389762878}],
#   [{'label': 'neutral', 'score': 0.8315011858940125}],
#   [{'label': 'neutral', 'score': 0.8861855268478394}],
#   [{'label': 'neutral', 'score': 0.8856730461120605}],
#   [{'label': 'neutral', 'score': 0.8353820443153381}],
#   [{'label': 'neutral', 'score': 0.8219995498657227}],
#   [{'label': 'neutral', 'score': 0.8201838135719299}],
#   [{'label': 'neutral', 'score': 0.85307776927948}],
#   [{'label': 'neutral', 'score': 0.8351284265518188}],
#   [{'label': 'neutral', 'score': 0.8434868454933167}],
#   [{'label': 'neutral', 'score': 0.8072768449783325}],
#   [{'label': 'neutral', 'score': 0.8770371675491333}],
#   [{'label': 'neutral', 'score': 0.8023079633712769}],
#   [{'label': 'neutral', 'score': 0.7795501351356506}],
#   [{'label': 'neutral', 'score': 0.8024011850357056}],
#   [{'label': 'neutral', 'score': 0.8163650631904602}],
#   [{'label': 'neutral', 'score': 0.8183712959289551}],
#   [{'label': 'neutral', 'score': 0.8122573494911194}],
#   [{'label': 'neutral', 'score': 0.8129602074623108}],
#   [{'label': 'neutral', 'score': 0.869245707988739}],
#   [{'label': 'neutral', 'score': 0.8350855708122253}],
#   [{'label': 'neutral', 'score': 0.7841210961341858}],
#   [{'label': 'neutral', 'score': 0.8464418053627014}],
#   [{'label': 'neutral', 'score': 0.8847141265869141}],
#   [{'label': 'neutral', 'score': 0.7904599905014038}],
#   [{'label': 'neutral', 'score': 0.7831265926361084}],
#   [{'label': 'neutral', 'score': 0.8085120320320129}],
#   [{'label': 'neutral', 'score': 0.7803395390510559}],
#   [{'label': 'neutral', 'score': 0.8307462930679321}],
#   [{'label': 'neutral', 'score': 0.8385668992996216}],
#   [{'label': 'neutral', 'score': 0.7777713537216187}],
#   [{'label': 'neutral', 'score': 0.8376911282539368}],
#   [{'label': 'neutral', 'score': 0.8234125375747681}],
#   [{'label': 'neutral', 'score': 0.8729861974716187}],
#   [{'label': 'neutral', 'score': 0.8015533089637756}],
#   [{'label': 'neutral', 'score': 0.8270345330238342}],
#   [{'label': 'neutral', 'score': 0.8004009127616882}],
#   [{'label': 'neutral', 'score': 0.7938750982284546}],
#   [{'label': 'neutral', 'score': 0.7882065773010254}],
#   [{'label': 'neutral', 'score': 0.8558237552642822}],
#   [{'label': 'neutral', 'score': 0.8708819150924683}],
#   [{'label': 'neutral', 'score': 0.8195033669471741}],
#   [{'label': 'neutral', 'score': 0.8214693665504456}],
#   [{'label': 'neutral', 'score': 0.8354458212852478}],
#   [{'label': 'neutral', 'score': 0.8024628758430481}],
#   [{'label': 'neutral', 'score': 0.8103060722351074}],
#   [{'label': 'neutral', 'score': 0.8063681721687317}],
#   [{'label': 'neutral', 'score': 0.8294121623039246}],
#   [{'label': 'neutral', 'score': 0.8217922449111938}],
#   [{'label': 'neutral', 'score': 0.8418050408363342}],
#   [{'label': 'neutral', 'score': 0.8043561577796936}],
#   [{'label': 'neutral', 'score': 0.8268657922744751}],
#   [{'label': 'neutral', 'score': 0.8239098191261292}],
#   [{'label': 'neutral', 'score': 0.8231824636459351}],
#   [{'label': 'neutral', 'score': 0.8241127133369446}],
#   [{'label': 'neutral', 'score': 0.790070116519928}],
#   [{'label': 'neutral', 'score': 0.7541301846504211}],
#   [{'label': 'neutral', 'score': 0.814055860042572}],
#   [{'label': 'neutral', 'score': 0.7795628905296326}],
#   [{'label': 'neutral', 'score': 0.7880948781967163}],
#   [{'label': 'neutral', 'score': 0.8679919838905334}],
#   [{'label': 'neutral', 'score': 0.8425087928771973}],
#   [{'label': 'neutral', 'score': 0.8173466324806213}],
#   [{'label': 'neutral', 'score': 0.8145840167999268}],
#   [{'label': 'neutral', 'score': 0.8171228170394897}],
#   [{'label': 'neutral', 'score': 0.8464891910552979}],
#   [{'label': 'neutral', 'score': 0.8212677836418152}],
#   [{'label': 'neutral', 'score': 0.8160538077354431}],
#   [{'label': 'neutral', 'score': 0.7659685611724854}],
#   [{'label': 'neutral', 'score': 0.8219218850135803}],
#   [{'label': 'neutral', 'score': 0.8138188719749451}],
#   [{'label': 'neutral', 'score': 0.8058919310569763}],
#   [{'label': 'neutral', 'score': 0.850233793258667}],
#   [{'label': 'neutral', 'score': 0.7753345370292664}],
#   [{'label': 'neutral', 'score': 0.8468223810195923}],
#   [{'label': 'neutral', 'score': 0.8059670329093933}],
#   [{'label': 'neutral', 'score': 0.8095452785491943}],
#   [{'label': 'neutral', 'score': 0.8393146991729736}],
#   [{'label': 'neutral', 'score': 0.8132932782173157}],
#   [{'label': 'neutral', 'score': 0.7957631945610046}],
#   [{'label': 'neutral', 'score': 0.7605018615722656}],
#   [{'label': 'neutral', 'score': 0.8661702871322632}],
#   [{'label': 'neutral', 'score': 0.830356776714325}],
#   [{'label': 'neutral', 'score': 0.8264133334159851}],
#   [{'label': 'neutral', 'score': 0.8336672782897949}],
#   [{'label': 'neutral', 'score': 0.8443545699119568}],
#   [{'label': 'neutral', 'score': 0.8553813099861145}],
#   [{'label': 'neutral', 'score': 0.854579746723175}],
#   [{'label': 'neutral', 'score': 0.8374485373497009}],
#   [{'label': 'neutral', 'score': 0.8102094531059265}],
#   [{'label': 'neutral', 'score': 0.8271060585975647}],
#   [{'label': 'neutral', 'score': 0.8742761611938477}],
#   [{'label': 'neutral', 'score': 0.8333853483200073}],
#   [{'label': 'neutral', 'score': 0.8270639777183533}],
#   [{'label': 'neutral', 'score': 0.8362569212913513}],
#   [{'label': 'neutral', 'score': 0.8264636993408203}],
#   [{'label': 'neutral', 'score': 0.829973042011261}],
#   [{'label': 'neutral', 'score': 0.847332239151001}],
#   [{'label': 'neutral', 'score': 0.8142157793045044}],
#   [{'label': 'neutral', 'score': 0.810088038444519}],
#   [{'label': 'neutral', 'score': 0.7762869596481323}],
#   [{'label': 'neutral', 'score': 0.8151193261146545}],
#   [{'label': 'neutral', 'score': 0.8030133843421936}],
#   [{'label': 'neutral', 'score': 0.8567914962768555}],
#   [{'label': 'neutral', 'score': 0.823264479637146}],
#   [{'label': 'neutral', 'score': 0.8605039119720459}],
#   [{'label': 'neutral', 'score': 0.8506316542625427}],
#   [{'label': 'neutral', 'score': 0.8120754361152649}],
#   [{'label': 'neutral', 'score': 0.7973194718360901}],
#   [{'label': 'neutral', 'score': 0.8234564661979675}],
#   [{'label': 'neutral', 'score': 0.8447298407554626}],
#   [{'label': 'neutral', 'score': 0.8299012780189514}],
#   [{'label': 'neutral', 'score': 0.8322861790657043}],
#   [{'label': 'neutral', 'score': 0.8516563177108765}],
#   [{'label': 'neutral', 'score': 0.7989699244499207}],
#   [{'label': 'neutral', 'score': 0.8394265174865723}],
#   [{'label': 'neutral', 'score': 0.7740079760551453}],
#   [{'label': 'neutral', 'score': 0.7955913543701172}],
#   [{'label': 'neutral', 'score': 0.8005664944648743}],
#   [{'label': 'neutral', 'score': 0.8578320741653442}],
#   [{'label': 'neutral', 'score': 0.8000726103782654}],
#   [{'label': 'neutral', 'score': 0.7995846271514893}],
#   [{'label': 'neutral', 'score': 0.8042574524879456}],
#   [{'label': 'neutral', 'score': 0.7906304597854614}],
#   [{'label': 'neutral', 'score': 0.8028403520584106}],
#   [{'label': 'neutral', 'score': 0.7962492108345032}],
#   [{'label': 'neutral', 'score': 0.8066255450248718}],
#   [{'label': 'neutral', 'score': 0.8021863698959351}],
#   [{'label': 'neutral', 'score': 0.7943688631057739}],
#   [{'label': 'neutral', 'score': 0.7922826409339905}],
#   [{'label': 'neutral', 'score': 0.7988295555114746}],
#   [{'label': 'neutral', 'score': 0.818327009677887}],
#   [{'label': 'neutral', 'score': 0.7958248257637024}],
#   [{'label': 'neutral', 'score': 0.8430861830711365}],
#   [{'label': 'neutral', 'score': 0.7981442213058472}],
#   [{'label': 'neutral', 'score': 0.8018151521682739}],
#   [{'label': 'neutral', 'score': 0.7753688097000122}],
#   [{'label': 'neutral', 'score': 0.8298466205596924}],
#   [{'label': 'neutral', 'score': 0.8487439751625061}],
#   [{'label': 'neutral', 'score': 0.8607574105262756}],
#   [{'label': 'neutral', 'score': 0.848897397518158}],
#   [{'label': 'neutral', 'score': 0.8706424832344055}],
#   [{'label': 'neutral', 'score': 0.8159830570220947}],
#   [{'label': 'neutral', 'score': 0.8072521090507507}],
#   [{'label': 'neutral', 'score': 0.8157679438591003}],
#   [{'label': 'neutral', 'score': 0.8492394685745239}],
#   [{'label': 'neutral', 'score': 0.822601854801178}],
#   [{'label': 'neutral', 'score': 0.7963224649429321}],
#   [{'label': 'neutral', 'score': 0.8296607136726379}],
#   [{'label': 'neutral', 'score': 0.7893903255462646}],
#   [{'label': 'neutral', 'score': 0.7824769020080566}],
#   [{'label': 'neutral', 'score': 0.8243911862373352}],
#   [{'label': 'neutral', 'score': 0.8586967587471008}],
#   [{'label': 'neutral', 'score': 0.8432450890541077}],
#   [{'label': 'neutral', 'score': 0.8194482922554016}],
#   [{'label': 'neutral', 'score': 0.8151782155036926}],
#   [{'label': 'neutral', 'score': 0.8243758678436279}],
#   [{'label': 'neutral', 'score': 0.8220224976539612}],
#   [{'label': 'neutral', 'score': 0.8233511447906494}],
#   [{'label': 'neutral', 'score': 0.8617016077041626}],
#   [{'label': 'neutral', 'score': 0.8296917676925659}],
#   [{'label': 'neutral', 'score': 0.7975307106971741}],
#   [{'label': 'neutral', 'score': 0.803439199924469}],
#   [{'label': 'neutral', 'score': 0.8014422655105591}],
#   [{'label': 'neutral', 'score': 0.8389403223991394}],
#   [{'label': 'neutral', 'score': 0.818637490272522}],
#   [{'label': 'neutral', 'score': 0.8393680453300476}],
#   [{'label': 'neutral', 'score': 0.87814861536026}],
#   [{'label': 'neutral', 'score': 0.8242921233177185}],
#   [{'label': 'neutral', 'score': 0.8397095799446106}],
#   [{'label': 'neutral', 'score': 0.8276506662368774}],
#   [{'label': 'neutral', 'score': 0.8365618586540222}],
#   [{'label': 'neutral', 'score': 0.7951919436454773}],
#   [{'label': 'neutral', 'score': 0.8008918762207031}],
#   [{'label': 'neutral', 'score': 0.801993727684021}],
#   [{'label': 'neutral', 'score': 0.8115525245666504}],
#   [{'label': 'neutral', 'score': 0.8229789733886719}],
#   [{'label': 'neutral', 'score': 0.7805837392807007}],
#   [{'label': 'neutral', 'score': 0.8186219334602356}],
#   [{'label': 'neutral', 'score': 0.8310101628303528}],
#   [{'label': 'neutral', 'score': 0.8800085783004761}],
#   [{'label': 'neutral', 'score': 0.9218423962593079}],
#   [{'label': 'neutral', 'score': 0.9040800333023071}],
#   [{'label': 'neutral', 'score': 0.9178738594055176}],
#   [{'label': 'neutral', 'score': 0.9067469239234924}],
#   [{'label': 'neutral', 'score': 0.9074933528900146}],
#   [{'label': 'neutral', 'score': 0.7932039499282837}],
#   [{'label': 'neutral', 'score': 0.8204211592674255}],
#   [{'label': 'neutral', 'score': 0.820277750492096}],
#   [{'label': 'neutral', 'score': 0.8389646410942078}],
#   [{'label': 'neutral', 'score': 0.8395810127258301}],
#   [{'label': 'neutral', 'score': 0.8700342774391174}],
#   [{'label': 'neutral', 'score': 0.8563821911811829}],
#   [{'label': 'neutral', 'score': 0.8247631192207336}],
#   [{'label': 'neutral', 'score': 0.8221666216850281}],
#   [{'label': 'neutral', 'score': 0.8505288362503052}],
#   [{'label': 'neutral', 'score': 0.8318909406661987}],
#   [{'label': 'neutral', 'score': 0.8478723168373108}],
#   [{'label': 'neutral', 'score': 0.8334180116653442}],
#   [{'label': 'neutral', 'score': 0.864477813243866}],
#   [{'label': 'neutral', 'score': 0.8174231648445129}],
#   [{'label': 'neutral', 'score': 0.8293095827102661}],
#   [{'label': 'neutral', 'score': 0.8627581596374512}],
#   [{'label': 'neutral', 'score': 0.804854154586792}],
#   [{'label': 'neutral', 'score': 0.8089094161987305}],
#   [{'label': 'neutral', 'score': 0.8367623686790466}],
#   [{'label': 'neutral', 'score': 0.8131752610206604}],
#   [{'label': 'neutral', 'score': 0.8019916415214539}],
#   [{'label': 'neutral', 'score': 0.8053827881813049}],
#   [{'label': 'neutral', 'score': 0.8171676993370056}],
#   [{'label': 'neutral', 'score': 0.7966286540031433}],
#   [{'label': 'neutral', 'score': 0.8451281785964966}],
#   [{'label': 'neutral', 'score': 0.7861073613166809}],
#   [{'label': 'neutral', 'score': 0.8229866027832031}],
#   [{'label': 'neutral', 'score': 0.8270682692527771}],
#   [{'label': 'neutral', 'score': 0.8304295539855957}],
#   [{'label': 'neutral', 'score': 0.8338932991027832}],
#   [{'label': 'neutral', 'score': 0.813045084476471}],
#   [{'label': 'neutral', 'score': 0.8339399695396423}],
#   [{'label': 'neutral', 'score': 0.8301456570625305}],
#   [{'label': 'neutral', 'score': 0.8237926363945007}],
#   [{'label': 'neutral', 'score': 0.8377527594566345}],
#   [{'label': 'neutral', 'score': 0.8409749269485474}],
#   [{'label': 'neutral', 'score': 0.8017016649246216}],
#   [{'label': 'neutral', 'score': 0.7933929562568665}],
#   [{'label': 'neutral', 'score': 0.8405407667160034}],
#   [{'label': 'neutral', 'score': 0.8335934281349182}],
#   [{'label': 'neutral', 'score': 0.7996753454208374}],
#   [{'label': 'neutral', 'score': 0.828474223613739}],
#   [{'label': 'neutral', 'score': 0.8557321429252625}],
#   [{'label': 'neutral', 'score': 0.8530526757240295}],
#   [{'label': 'neutral', 'score': 0.8557664752006531}],
#   [{'label': 'neutral', 'score': 0.8560305237770081}],
#   [{'label': 'neutral', 'score': 0.8023020029067993}],
#   [{'label': 'neutral', 'score': 0.8383694887161255}],
#   [{'label': 'neutral', 'score': 0.8406968712806702}],
#   [{'label': 'neutral', 'score': 0.825410008430481}],
#   [{'label': 'neutral', 'score': 0.833994448184967}],
#   [{'label': 'neutral', 'score': 0.8438661098480225}],
#   [{'label': 'neutral', 'score': 0.8270549774169922}],
#   [{'label': 'neutral', 'score': 0.8026386499404907}],
#   [{'label': 'neutral', 'score': 0.8378403186798096}],
#   [{'label': 'neutral', 'score': 0.8147884607315063}],
#   [{'label': 'neutral', 'score': 0.8348885774612427}],
#   [{'label': 'neutral', 'score': 0.8252008557319641}],
#   [{'label': 'neutral', 'score': 0.8348401188850403}],
#   [{'label': 'neutral', 'score': 0.8557533621788025}],
#   [{'label': 'neutral', 'score': 0.8229649662971497}],
#   [{'label': 'neutral', 'score': 0.8462446928024292}],
#   [{'label': 'neutral', 'score': 0.8453563451766968}],
#   [{'label': 'neutral', 'score': 0.8487228751182556}],
#   [{'label': 'neutral', 'score': 0.8485583066940308}],
#   [{'label': 'neutral', 'score': 0.8130771517753601}],
#   [{'label': 'neutral', 'score': 0.8539443016052246}],
#   [{'label': 'neutral', 'score': 0.8019425868988037}],
#   [{'label': 'neutral', 'score': 0.8221871852874756}],
#   [{'label': 'neutral', 'score': 0.8013973832130432}],
#   [{'label': 'neutral', 'score': 0.8425767421722412}],
#   [{'label': 'neutral', 'score': 0.8564621210098267}],
#   [{'label': 'neutral', 'score': 0.8446469902992249}],
#   [{'label': 'neutral', 'score': 0.8137909173965454}],
#   [{'label': 'neutral', 'score': 0.8070782423019409}],
#   [{'label': 'neutral', 'score': 0.8147333860397339}],
#   [{'label': 'neutral', 'score': 0.8048609495162964}],
#   [{'label': 'neutral', 'score': 0.7694377899169922}],
#   [{'label': 'neutral', 'score': 0.8192511796951294}],
#   [{'label': 'neutral', 'score': 0.8174867630004883}],
#   [{'label': 'neutral', 'score': 0.8148589134216309}],
#   [{'label': 'neutral', 'score': 0.804578423500061}],
#   [{'label': 'neutral', 'score': 0.8133324980735779}],
#   [{'label': 'neutral', 'score': 0.787768542766571}],
#   [{'label': 'neutral', 'score': 0.785962700843811}],
#   [{'label': 'neutral', 'score': 0.8483648896217346}],
#   [{'label': 'neutral', 'score': 0.783522367477417}],
#   [{'label': 'neutral', 'score': 0.7816207408905029}],
#   [{'label': 'neutral', 'score': 0.800200879573822}],
#   [{'label': 'neutral', 'score': 0.8021556735038757}],
#   [{'label': 'neutral', 'score': 0.7993144989013672}],
#   [{'label': 'neutral', 'score': 0.8368775844573975}],
#   [{'label': 'neutral', 'score': 0.7984592914581299}],
#   [{'label': 'neutral', 'score': 0.810529887676239}],
#   [{'label': 'neutral', 'score': 0.8274379968643188}],
#   [{'label': 'neutral', 'score': 0.8244804739952087}],
#   [{'label': 'neutral', 'score': 0.8114326000213623}],
#   [{'label': 'neutral', 'score': 0.8651919364929199}],
#   [{'label': 'neutral', 'score': 0.8037486672401428}],
#   [{'label': 'neutral', 'score': 0.8190974593162537}],
#   [{'label': 'neutral', 'score': 0.8150976300239563}],
#   [{'label': 'neutral', 'score': 0.807702362537384}],
#   [{'label': 'neutral', 'score': 0.8035793900489807}],
#   [{'label': 'neutral', 'score': 0.8192303776741028}],
#   [{'label': 'neutral', 'score': 0.8400878310203552}],
#   [{'label': 'neutral', 'score': 0.8288256525993347}]],
#  'financial_news_roberta': [[{'label': 'neutral',
#     'score': 0.9997852444648743}],
#   [{'label': 'neutral', 'score': 0.9997325539588928}],
#   [{'label': 'neutral', 'score': 0.9998261332511902}],
#   [{'label': 'neutral', 'score': 0.9997463822364807}],
#   [{'label': 'neutral', 'score': 0.9997592568397522}],
#   [{'label': 'neutral', 'score': 0.999729335308075}],
#   [{'label': 'neutral', 'score': 0.9997974038124084}],
#   [{'label': 'neutral', 'score': 0.9997770190238953}],
#   [{'label': 'neutral', 'score': 0.9997820258140564}],
#   [{'label': 'neutral', 'score': 0.9997124075889587}],
#   [{'label': 'neutral', 'score': 0.9998103976249695}],
#   [{'label': 'neutral', 'score': 0.9998347759246826}],
#   [{'label': 'neutral', 'score': 0.999768078327179}],
#   [{'label': 'neutral', 'score': 0.999725878238678}],
#   [{'label': 'neutral', 'score': 0.9997811913490295}],
#   [{'label': 'neutral', 'score': 0.9997361302375793}],
#   [{'label': 'neutral', 'score': 0.9997641444206238}],
#   [{'label': 'neutral', 'score': 0.999825656414032}],
#   [{'label': 'neutral', 'score': 0.9997193217277527}],
#   [{'label': 'neutral', 'score': 0.9997182488441467}],
#   [{'label': 'neutral', 'score': 0.9997236132621765}],
#   [{'label': 'neutral', 'score': 0.9996408224105835}],
#   [{'label': 'neutral', 'score': 0.9996209144592285}],
#   [{'label': 'neutral', 'score': 0.9995200634002686}],
#   [{'label': 'neutral', 'score': 0.999721348285675}],
#   [{'label': 'neutral', 'score': 0.9998154044151306}],
#   [{'label': 'neutral', 'score': 0.9997422099113464}],
#   [{'label': 'neutral', 'score': 0.9996641874313354}],
#   [{'label': 'neutral', 'score': 0.9997087121009827}],
#   [{'label': 'neutral', 'score': 0.9998430013656616}],
#   [{'label': 'neutral', 'score': 0.9998201727867126}],
#   [{'label': 'neutral', 'score': 0.999731719493866}],
#   [{'label': 'neutral', 'score': 0.9996987581253052}],
#   [{'label': 'neutral', 'score': 0.9997269511222839}],
#   [{'label': 'neutral', 'score': 0.9996944665908813}],
#   [{'label': 'neutral', 'score': 0.9998111128807068}],
#   [{'label': 'neutral', 'score': 0.9998151659965515}],
#   [{'label': 'neutral', 'score': 0.9996798038482666}],
#   [{'label': 'neutral', 'score': 0.9998488426208496}],
#   [{'label': 'neutral', 'score': 0.9997888207435608}],
#   [{'label': 'neutral', 'score': 0.9997841715812683}],
#   [{'label': 'neutral', 'score': 0.9996803998947144}],
#   [{'label': 'neutral', 'score': 0.9997366070747375}],
#   [{'label': 'neutral', 'score': 0.9998238682746887}],
#   [{'label': 'neutral', 'score': 0.9996316432952881}],
#   [{'label': 'neutral', 'score': 0.9998164772987366}],
#   [{'label': 'neutral', 'score': 0.9997199177742004}],
#   [{'label': 'neutral', 'score': 0.9996613264083862}],
#   [{'label': 'neutral', 'score': 0.999758780002594}],
#   [{'label': 'neutral', 'score': 0.9998093247413635}],
#   [{'label': 'neutral', 'score': 0.9998347759246826}],
#   [{'label': 'neutral', 'score': 0.9997884631156921}],
#   [{'label': 'neutral', 'score': 0.9998263716697693}],
#   [{'label': 'neutral', 'score': 0.9997349381446838}],
#   [{'label': 'neutral', 'score': 0.9997571110725403}],
#   [{'label': 'neutral', 'score': 0.9998049139976501}],
#   [{'label': 'neutral', 'score': 0.999826967716217}],
#   [{'label': 'neutral', 'score': 0.9997954964637756}],
#   [{'label': 'neutral', 'score': 0.9998243451118469}],
#   [{'label': 'neutral', 'score': 0.9997863173484802}],
#   [{'label': 'neutral', 'score': 0.9997320771217346}],
#   [{'label': 'neutral', 'score': 0.99982750415802}],
#   [{'label': 'neutral', 'score': 0.9998276233673096}],
#   [{'label': 'neutral', 'score': 0.9997923970222473}],
#   [{'label': 'neutral', 'score': 0.9997655749320984}],
#   [{'label': 'neutral', 'score': 0.9996566772460938}],
#   [{'label': 'neutral', 'score': 0.9997201561927795}],
#   [{'label': 'neutral', 'score': 0.9997071623802185}],
#   [{'label': 'neutral', 'score': 0.9997370839118958}],
#   [{'label': 'neutral', 'score': 0.9997624754905701}],
#   [{'label': 'neutral', 'score': 0.9998372793197632}],
#   [{'label': 'neutral', 'score': 0.9998070597648621}],
#   [{'label': 'neutral', 'score': 0.9997891783714294}],
#   [{'label': 'neutral', 'score': 0.9998314380645752}],
#   [{'label': 'neutral', 'score': 0.999819815158844}],
#   [{'label': 'neutral', 'score': 0.9998363256454468}],
#   [{'label': 'neutral', 'score': 0.9997648596763611}],
#   [{'label': 'neutral', 'score': 0.999685525894165}],
#   [{'label': 'neutral', 'score': 0.9998093247413635}],
#   [{'label': 'neutral', 'score': 0.9998455047607422}],
#   [{'label': 'neutral', 'score': 0.9997751116752625}],
#   [{'label': 'neutral', 'score': 0.999609649181366}],
#   [{'label': 'neutral', 'score': 0.999750554561615}],
#   [{'label': 'neutral', 'score': 0.9997807145118713}],
#   [{'label': 'neutral', 'score': 0.9997640252113342}],
#   [{'label': 'neutral', 'score': 0.9995900988578796}],
#   [{'label': 'neutral', 'score': 0.9997513890266418}],
#   [{'label': 'neutral', 'score': 0.9998049139976501}],
#   [{'label': 'neutral', 'score': 0.9997308850288391}],
#   [{'label': 'neutral', 'score': 0.9997228980064392}],
#   [{'label': 'neutral', 'score': 0.9997765421867371}],
#   [{'label': 'neutral', 'score': 0.999710738658905}],
#   [{'label': 'neutral', 'score': 0.9997757077217102}],
#   [{'label': 'neutral', 'score': 0.9997827410697937}],
#   [{'label': 'neutral', 'score': 0.9997374415397644}],
#   [{'label': 'neutral', 'score': 0.9997723698616028}],
#   [{'label': 'neutral', 'score': 0.9997485280036926}],
#   [{'label': 'neutral', 'score': 0.9997720122337341}],
#   [{'label': 'neutral', 'score': 0.9997422099113464}],
#   [{'label': 'neutral', 'score': 0.9997612833976746}],
#   [{'label': 'neutral', 'score': 0.9998328685760498}],
#   [{'label': 'neutral', 'score': 0.9998252987861633}],
#   [{'label': 'neutral', 'score': 0.9998401403427124}],
#   [{'label': 'neutral', 'score': 0.9997184872627258}],
#   [{'label': 'neutral', 'score': 0.999803364276886}],
#   [{'label': 'neutral', 'score': 0.9997795224189758}],
#   [{'label': 'neutral', 'score': 0.9998266100883484}],
#   [{'label': 'neutral', 'score': 0.9997958540916443}],
#   [{'label': 'neutral', 'score': 0.9997403025627136}],
#   [{'label': 'neutral', 'score': 0.9997877478599548}],
#   [{'label': 'neutral', 'score': 0.9996771812438965}],
#   [{'label': 'neutral', 'score': 0.9998458623886108}],
#   [{'label': 'neutral', 'score': 0.9997219443321228}],
#   [{'label': 'neutral', 'score': 0.9998317956924438}],
#   [{'label': 'neutral', 'score': 0.999728262424469}],
#   [{'label': 'neutral', 'score': 0.9997914433479309}],
#   [{'label': 'neutral', 'score': 0.9997584223747253}],
#   [{'label': 'neutral', 'score': 0.9997900128364563}],
#   [{'label': 'neutral', 'score': 0.9995548129081726}],
#   [{'label': 'neutral', 'score': 0.9998217225074768}],
#   [{'label': 'neutral', 'score': 0.999765932559967}],
#   [{'label': 'neutral', 'score': 0.9997226595878601}],
#   [{'label': 'neutral', 'score': 0.9998512268066406}],
#   [{'label': 'neutral', 'score': 0.9998242259025574}],
#   [{'label': 'neutral', 'score': 0.999647855758667}],
#   [{'label': 'neutral', 'score': 0.9997316002845764}],
#   [{'label': 'neutral', 'score': 0.9996401071548462}],
#   [{'label': 'neutral', 'score': 0.9995961785316467}],
#   [{'label': 'neutral', 'score': 0.9998158812522888}],
#   [{'label': 'neutral', 'score': 0.9997866749763489}],
#   [{'label': 'neutral', 'score': 0.9995675683021545}],
#   [{'label': 'neutral', 'score': 0.9997072815895081}],
#   [{'label': 'neutral', 'score': 0.9996814727783203}],
#   [{'label': 'neutral', 'score': 0.9996452331542969}],
#   [{'label': 'neutral', 'score': 0.99981290102005}],
#   [{'label': 'neutral', 'score': 0.9997398257255554}],
#   [{'label': 'neutral', 'score': 0.999799907207489}],
#   [{'label': 'neutral', 'score': 0.9997407793998718}],
#   [{'label': 'neutral', 'score': 0.9995071887969971}],
#   [{'label': 'neutral', 'score': 0.9996358156204224}],
#   [{'label': 'neutral', 'score': 0.9996868371963501}],
#   [{'label': 'neutral', 'score': 0.9996803998947144}],
#   [{'label': 'neutral', 'score': 0.9998045563697815}],
#   [{'label': 'neutral', 'score': 0.9998281002044678}],
#   [{'label': 'neutral', 'score': 0.9997050166130066}],
#   [{'label': 'neutral', 'score': 0.9998219609260559}],
#   [{'label': 'neutral', 'score': 0.999678373336792}],
#   [{'label': 'neutral', 'score': 0.9997530579566956}],
#   [{'label': 'neutral', 'score': 0.999729573726654}],
#   [{'label': 'neutral', 'score': 0.9998254179954529}],
#   [{'label': 'neutral', 'score': 0.9997527003288269}],
#   [{'label': 'neutral', 'score': 0.9997840523719788}],
#   [{'label': 'neutral', 'score': 0.9998412132263184}],
#   [{'label': 'neutral', 'score': 0.9998101592063904}],
#   [{'label': 'neutral', 'score': 0.9998170733451843}],
#   [{'label': 'neutral', 'score': 0.9998229146003723}],
#   [{'label': 'neutral', 'score': 0.9997937083244324}],
#   [{'label': 'neutral', 'score': 0.9996681213378906}],
#   [{'label': 'neutral', 'score': 0.9997332692146301}],
#   [{'label': 'neutral', 'score': 0.9997743964195251}],
#   [{'label': 'neutral', 'score': 0.9997426867485046}],
#   [{'label': 'neutral', 'score': 0.9996238946914673}],
#   [{'label': 'neutral', 'score': 0.9998482465744019}],
#   [{'label': 'neutral', 'score': 0.9998038411140442}],
#   [{'label': 'neutral', 'score': 0.9997301697731018}],
#   [{'label': 'neutral', 'score': 0.9996196031570435}],
#   [{'label': 'neutral', 'score': 0.9996883869171143}],
#   [{'label': 'neutral', 'score': 0.9997047781944275}],
#   [{'label': 'neutral', 'score': 0.9997034668922424}],
#   [{'label': 'neutral', 'score': 0.9998461008071899}],
#   [{'label': 'neutral', 'score': 0.99980229139328}],
#   [{'label': 'neutral', 'score': 0.9997645020484924}],
#   [{'label': 'neutral', 'score': 0.9997881054878235}],
#   [{'label': 'neutral', 'score': 0.999785840511322}],
#   [{'label': 'neutral', 'score': 0.999822199344635}],
#   [{'label': 'neutral', 'score': 0.9997966885566711}],
#   [{'label': 'neutral', 'score': 0.9998325109481812}],
#   [{'label': 'neutral', 'score': 0.9997542500495911}],
#   [{'label': 'neutral', 'score': 0.999828577041626}],
#   [{'label': 'neutral', 'score': 0.9998329877853394}],
#   [{'label': 'neutral', 'score': 0.9997854828834534}],
#   [{'label': 'neutral', 'score': 0.9997559189796448}],
#   [{'label': 'neutral', 'score': 0.9996914863586426}],
#   [{'label': 'neutral', 'score': 0.9996582269668579}],
#   [{'label': 'neutral', 'score': 0.9996875524520874}],
#   [{'label': 'neutral', 'score': 0.9996880292892456}],
#   [{'label': 'neutral', 'score': 0.9996520280838013}],
#   [{'label': 'neutral', 'score': 0.9996887445449829}],
#   [{'label': 'neutral', 'score': 0.9996353387832642}],
#   [{'label': 'neutral', 'score': 0.9997974038124084}],
#   [{'label': 'neutral', 'score': 0.9997996687889099}],
#   [{'label': 'neutral', 'score': 0.9997815489768982}],
#   [{'label': 'neutral', 'score': 0.999812662601471}],
#   [{'label': 'neutral', 'score': 0.9997619986534119}],
#   [{'label': 'neutral', 'score': 0.99977046251297}],
#   [{'label': 'neutral', 'score': 0.9997121691703796}],
#   [{'label': 'neutral', 'score': 0.9997672438621521}],
#   [{'label': 'neutral', 'score': 0.9998185038566589}],
#   [{'label': 'neutral', 'score': 0.9997419714927673}],
#   [{'label': 'neutral', 'score': 0.9998339414596558}],
#   [{'label': 'neutral', 'score': 0.999832272529602}],
#   [{'label': 'neutral', 'score': 0.9998342990875244}],
#   [{'label': 'neutral', 'score': 0.9997959733009338}],
#   [{'label': 'neutral', 'score': 0.9997407793998718}],
#   [{'label': 'neutral', 'score': 0.9998018145561218}],
#   [{'label': 'neutral', 'score': 0.9998440742492676}],
#   [{'label': 'neutral', 'score': 0.9998359680175781}],
#   [{'label': 'neutral', 'score': 0.9998348951339722}],
#   [{'label': 'neutral', 'score': 0.9998202919960022}],
#   [{'label': 'neutral', 'score': 0.9997890591621399}],
#   [{'label': 'neutral', 'score': 0.9998201727867126}],
#   [{'label': 'neutral', 'score': 0.9998248219490051}],
#   [{'label': 'neutral', 'score': 0.9998412132263184}],
#   [{'label': 'neutral', 'score': 0.9998219609260559}],
#   [{'label': 'neutral', 'score': 0.9998167157173157}],
#   [{'label': 'neutral', 'score': 0.9998247027397156}],
#   [{'label': 'neutral', 'score': 0.9998071789741516}],
#   [{'label': 'neutral', 'score': 0.9997683167457581}],
#   [{'label': 'neutral', 'score': 0.9997904896736145}],
#   [{'label': 'neutral', 'score': 0.9998095631599426}],
#   [{'label': 'neutral', 'score': 0.999760091304779}],
#   [{'label': 'neutral', 'score': 0.9997881054878235}],
#   [{'label': 'neutral', 'score': 0.9997105002403259}],
#   [{'label': 'neutral', 'score': 0.9997217059135437}],
#   [{'label': 'neutral', 'score': 0.999810516834259}],
#   [{'label': 'neutral', 'score': 0.9998182654380798}],
#   [{'label': 'neutral', 'score': 0.9998151659965515}],
#   [{'label': 'neutral', 'score': 0.9997333884239197}],
#   [{'label': 'neutral', 'score': 0.9997996687889099}],
#   [{'label': 'neutral', 'score': 0.9998229146003723}],
#   [{'label': 'neutral', 'score': 0.9998278617858887}],
#   [{'label': 'neutral', 'score': 0.9998407363891602}],
#   [{'label': 'neutral', 'score': 0.9998394250869751}],
#   [{'label': 'neutral', 'score': 0.9997403025627136}],
#   [{'label': 'neutral', 'score': 0.9997963309288025}],
#   [{'label': 'neutral', 'score': 0.9997332692146301}],
#   [{'label': 'neutral', 'score': 0.9997338652610779}],
#   [{'label': 'neutral', 'score': 0.999728262424469}],
#   [{'label': 'neutral', 'score': 0.9998199343681335}],
#   [{'label': 'neutral', 'score': 0.9998371601104736}],
#   [{'label': 'neutral', 'score': 0.9997891783714294}],
#   [{'label': 'neutral', 'score': 0.9998230338096619}],
#   [{'label': 'neutral', 'score': 0.999836802482605}],
#   [{'label': 'neutral', 'score': 0.9998121857643127}],
#   [{'label': 'neutral', 'score': 0.9997878670692444}],
#   [{'label': 'neutral', 'score': 0.9998489618301392}],
#   [{'label': 'neutral', 'score': 0.9997802376747131}],
#   [{'label': 'neutral', 'score': 0.9998101592063904}],
#   [{'label': 'neutral', 'score': 0.9998165965080261}],
#   [{'label': 'neutral', 'score': 0.9998100399971008}],
#   [{'label': 'neutral', 'score': 0.9997482895851135}],
#   [{'label': 'neutral', 'score': 0.9998414516448975}],
#   [{'label': 'neutral', 'score': 0.999832034111023}],
#   [{'label': 'neutral', 'score': 0.9998393058776855}],
#   [{'label': 'neutral', 'score': 0.9998087286949158}],
#   [{'label': 'neutral', 'score': 0.9998143315315247}],
#   [{'label': 'neutral', 'score': 0.9998146891593933}],
#   [{'label': 'neutral', 'score': 0.9998220801353455}],
#   [{'label': 'neutral', 'score': 0.9998487234115601}],
#   [{'label': 'neutral', 'score': 0.9998307228088379}],
#   [{'label': 'neutral', 'score': 0.9998025298118591}],
#   [{'label': 'neutral', 'score': 0.9998136162757874}],
#   [{'label': 'neutral', 'score': 0.9998053908348083}],
#   [{'label': 'neutral', 'score': 0.999840497970581}],
#   [{'label': 'neutral', 'score': 0.9997392296791077}],
#   [{'label': 'neutral', 'score': 0.999832272529602}],
#   [{'label': 'neutral', 'score': 0.9997779726982117}],
#   [{'label': 'neutral', 'score': 0.9997550845146179}],
#   [{'label': 'neutral', 'score': 0.9998151659965515}],
#   [{'label': 'neutral', 'score': 0.9997285008430481}],
#   [{'label': 'neutral', 'score': 0.9998090863227844}],
#   [{'label': 'neutral', 'score': 0.9997867941856384}],
#   [{'label': 'neutral', 'score': 0.9997099041938782}],
#   [{'label': 'neutral', 'score': 0.9997408986091614}],
#   [{'label': 'neutral', 'score': 0.9996242523193359}],
#   [{'label': 'neutral', 'score': 0.9998158812522888}],
#   [{'label': 'neutral', 'score': 0.9997373223304749}],
#   [{'label': 'neutral', 'score': 0.9997826218605042}],
#   [{'label': 'neutral', 'score': 0.9996662139892578}],
#   [{'label': 'neutral', 'score': 0.9997387528419495}],
#   [{'label': 'neutral', 'score': 0.9997182488441467}],
#   [{'label': 'neutral', 'score': 0.9994761347770691}],
#   [{'label': 'neutral', 'score': 0.9996458292007446}],
#   [{'label': 'neutral', 'score': 0.9996840953826904}],
#   [{'label': 'neutral', 'score': 0.9997366070747375}],
#   [{'label': 'neutral', 'score': 0.9996998310089111}],
#   [{'label': 'neutral', 'score': 0.9997238516807556}],
#   [{'label': 'neutral', 'score': 0.9996973276138306}],
#   [{'label': 'neutral', 'score': 0.999748170375824}],
#   [{'label': 'neutral', 'score': 0.9996752738952637}],
#   [{'label': 'neutral', 'score': 0.9997126460075378}],
#   [{'label': 'neutral', 'score': 0.9998019337654114}],
#   [{'label': 'neutral', 'score': 0.9997815489768982}],
#   [{'label': 'neutral', 'score': 0.9997913241386414}],
#   [{'label': 'neutral', 'score': 0.9998239874839783}],
#   [{'label': 'neutral', 'score': 0.9997692704200745}],
#   [{'label': 'neutral', 'score': 0.9997499585151672}],
#   [{'label': 'neutral', 'score': 0.9997885823249817}],
#   [{'label': 'neutral', 'score': 0.9997246861457825}],
#   [{'label': 'neutral', 'score': 0.9995446801185608}],
#   [{'label': 'neutral', 'score': 0.9997673630714417}],
#   [{'label': 'neutral', 'score': 0.9998233914375305}],
#   [{'label': 'neutral', 'score': 0.9998251795768738}]]}

# %%
# Map labels from negative, neutral, positive to non-hate, hate
def label_to_unified(label):
    if label == 'neutral' or label == 'positive':
        return 'non-hate'
    elif label == 'negative':
        return 'hate'
    return label

def map_to_hate_labels(dataset):
    for model, results in dataset.items():
        for i, result in enumerate(results):
            # Result is a list of dictionaries, where each dictionary has a 'label' key
            result = result[0]
            dataset[model][i] = label_to_unified(result['label'])
    return dataset

tweet_eval_results = map_to_hate_labels(tweet_eval_results)
financial_phrasebank_results = map_to_hate_labels(financial_phrasebank_results)

display(tweet_eval_results)
display(financial_phrasebank_results)
# Out:
# {'twitter_roberta': ['non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   ...],
#  'financial_news_roberta': ['non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   ...]}
# {'twitter_roberta': ['non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate'],
#  'financial_news_roberta': ['non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate',
#   'non-hate']}

# %%
# %pwd
# Out:
# 'D:\\UzK\\OpenLLMs-SS24-SentinAL\\notebooks'

# %%
from sklearn.metrics import classification_report

# Evaluate models on tweet eval dataset
for model, results in tweet_eval_results.items():
    y_true = [tweet_eval.features['label'].int2str(r) for r in tweet_eval['label']]
    y_pred = results
    print(f"Classification report tweet_eval for {model}")
    print(classification_report(y_true, y_pred))
    
    
# Evaluate models on financial phrasebank dataset
for model, results in financial_phrasebank_results.items():
    y_true = [label_to_unified(financial_phrasebank.features['label'].int2str(r)) for r in financial_phrasebank['label']]
    y_pred = results
    print(f"Classification report financial_phrasebank for {model}")
    print(classification_report(y_true, y_pred))
# Out:
# Classification report tweet_eval for twitter_roberta
#               precision    recall  f1-score   support
#
#         hate       1.00      0.00      0.00      1252
#     non-hate       0.00      0.00      0.00         0
#
#     accuracy                           0.00      1252
#    macro avg       0.50      0.00      0.00      1252
# weighted avg       1.00      0.00      0.00      1252
#
# Classification report tweet_eval for financial_news_roberta
#               precision    recall  f1-score   support
#
#         hate       0.00      0.00      0.00    1252.0
#     non-hate       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00    1252.0
#    macro avg       0.00      0.00      0.00    1252.0
# weighted avg       0.00      0.00      0.00    1252.0
#
# Classification report financial_phrasebank for twitter_roberta
#               precision    recall  f1-score   support
#
#         hate       0.00      0.00      0.00     303.0
#     non-hate       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00     303.0
#    macro avg       0.00      0.00      0.00     303.0
# weighted avg       0.00      0.00      0.00     303.0
#
# Classification report financial_phrasebank for financial_news_roberta
#               precision    recall  f1-score   support
#
#         hate       0.00      0.00      0.00     303.0
#     non-hate       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00     303.0
#    macro avg       0.00      0.00      0.00     303.0
# weighted avg       0.00      0.00      0.00     303.0
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\UzK\OpenLLMs-SS24-SentinAL\venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import dill

with open('../data/raw/tweet_homoglyph_eval_results.pkl', 'wb') as f:
    dill.dump(tweet_eval_results, f)
    
with open('../data/raw/financial_homoglyph_phrasebank_results.pkl', 'wb') as f:
    dill.dump(financial_phrasebank_results, f)
